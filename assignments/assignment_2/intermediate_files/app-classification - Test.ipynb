# %% [markdown]
# # Assignment: Application Classification

# %% [markdown]
# This assignment will focus on feature extraction, ML modeling, evaluation, and explainability. You will do this in the context of application classification.
#
# **Submission Instructions**:
# - You should submit a single notebook containing your code to extract features and model evaluation, and response to Part 3.
# - You should assume the CSVs are located in a folder called `data`, co-located with the notebook.
# - Make sure the notebook is styled well. Write code in the relevant sections of the notebook.
# - I should be able to run the entire notebook without any errors.

# %%
"""
SUBMITTED ON: 2025-04-23
AUTHOR: Manish Kumar, Pratham Agarwal

DESCRIPTION: 
The following .ipynb notebook includes functions for data cleaning, transformation, and visualization for classification done on ISCX VPN-nonVPN dataset.


RESULTS:
Accuracy: 
0.92      (simple RF)
0.91      (RF with 10 fold cross-validation)

"""

# %% [markdown]
# ## Dataset download and Warmup

# %% [markdown]
# We will use a public dataset, called [ISCXVPN2016](https://www.unb.ca/cic/datasets/vpn.html) that consists of annotated traffic logs. While the original dataset is available in the form of PCAPs, I have also shared the CSV files extracted from the PCAPs, available on [Onedrive](https://csciitd-my.sharepoint.com/:f:/g/personal/tmangla_iitd_ac_in/Ev5JYDW-YI5CjKq3XWgL0y8BdihJTCi4v4qA5Sn1UoKisQ?e=INZ5mJ). The data consists of TSV (tab-seprated) files with each file corresponding to a different application. Each row in the file corresponds to one packet for that application. The headers follow this schema:
# ```
# columns = ["frame.time_epoch", "frame.len", "ip.src", "ip.dst", "ip.proto",
#     "udp.srcport", "udp.dstport", "tcp.srcport", "tcp.dstport",
#     "tcp.flags", "tcp.flags.syn", "tcp.flags.fin", "dns.qry.name"]
# ```
#
# **Getting application ground truth:** You can use the filename of the CSV file

# %% [markdown]
# Download the dataset and read it. You can read the data in a dataframe:
# ```
# df = pd.read_csv(filename, sep="\t", header=None, names=columns)
# ```

# %%
# Installing Reqd. Packages
! pip install pandas numpy matplotlib seaborn scikit-learn

# %%
# Importing Libraries
import os
import pandas as pd
import numpy as np
import json
from collections import defaultdict
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import cross_val_score
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize

# %%
#--------------CONSTANTS-----------------
DATA_PATH = "data"
RESULTS_DIR = "results"
GROUPED_JSON_FILE = os.path.join(RESULTS_DIR, "grouped_classes.json")
OUTPUT_FLOWS_FILE = os.path.join(RESULTS_DIR, "flows.csv")
UDP_TIMEOUT = 30            # seconds, can be adjusted

# %%
def group_files_by_class(folder_path):
    """
    Groups files in the specified folder by class name.
    """
    
    print(f"Grouping files in folder: {folder_path}")
    files = [f for f in os.listdir(folder_path) if f.endswith('.csv')]              # Get list of all CSV files
    if not files:
        print("No CSV files found in the specified folder.")
        return

    grouped_files = defaultdict(list)                                               # Dictionary to hold grouped files

    for file in files:
        # Extract the class name before '_capture'
        class_name = '_'.join(file.split('_')[:2])                                  # vpn_skype-chat or nonvpn_rdp, etc.
        grouped_files[class_name].append(file)

    # Print grouped classes
    # for class_name, file_list in grouped_files.items():
        # print(f"\nClass: {class_name}")
        # for file in file_list:
            # print(f"  - {file}")

    # Save groupings to JSON file
    with open(GROUPED_JSON_FILE, 'w') as f:
        json.dump(grouped_files, f, indent=4)

    print(f"Grouped classes saved to '{GROUPED_JSON_FILE}'")
    return grouped_files

# %%
def get_bidirectional_key(src_ip, src_port, dst_ip, dst_port, protocol):
    """
    Returns a bidirectional key for the connection. {sets lower IP/port first}
    """
    
    if (src_ip, src_port) <= (dst_ip, dst_port):
        return (src_ip, src_port, dst_ip, dst_port, protocol)
    else:
        return (dst_ip, dst_port, src_ip, src_port, protocol)

# %%
def process_files(grouped_files, folder_path, output_file):
    """
    Processes files in the specified folder and extracts flows.
    """
    
    flow_index = 1
    all_flows = []
    total_flows = 0
    
    # Iterate through each class and its corresponding files
    for label, files in grouped_files.items():
        # Initialize a dictionary to hold flow data
        # Each flow is defined by 5-tuple (src_ip, src_port, dst_ip, dst_port, protocol)
        flows = defaultdict(lambda: {
            "timestamps": [], "sizes": [], "directions": [],
            "label": label, "last_ts": None, "proto": None,
            "first_seen": None, "syn_seen": False, "initiator": None
        })

        for index, file in enumerate(files):
            file_path = os.path.join(folder_path, file)
            try:
                df = pd.read_csv(file_path, sep='\t', header=None, names=[
                    "frame.time_epoch", "frame.len", "ip.src", "ip.dst", "ip.proto",
                    "udp.srcport", "udp.dstport", "tcp.srcport", "tcp.dstport",
                    "tcp.flags", "tcp.flags.syn", "tcp.flags.fin", 
                    "dns.qry.name"], dtype={4:str, 12: str})

                print(f"[{index + 1:02}/{len(files):02}] Processing file: {os.path.basename(file_path)}")
                # print("Initial packets:", len(df))

                # Drop rows with missing frame.len, ip.src or ip.dst
                df = df.dropna(subset=["frame.len", "ip.src", "ip.dst"])
                # print(len(df), "packets after dropping NaN values")
                
                # Also, ensure that ip.proto is numeric
                df = df[df["ip.proto"].str.match(r"^\d+$", na=False)]
                df["ip.proto"] = df["ip.proto"].astype(int)        
                # print(len(df), "packets after filtering for numeric ip.proto")

                # Filter for TCP and UDP packets only
                df = df[(df["ip.proto"] == 6) | (df["ip.proto"] == 17)]
                # print(len(df), "packets after filtering for TCP/UDP")

                # Also, filter out DNS queries (where dns.qry.name is not NaN)
                df = df[df["dns.qry.name"].isna()]
                # print(len(df), "packets after filtering out DNS queries")

                # Convert relevant columns to appropriate types
                df["frame.time_epoch"] = df["frame.time_epoch"].astype(float)
                df["frame.len"] = df["frame.len"].astype(int)

                # print(f"Class: {label}, Number of packets: {len(df)}")

                # Iterate through the DataFrame rows to extract flow data
                # For each packet, check if it's TCP or UDP and process accordingly
                for _, row in df.iterrows():
                    ts = row["frame.time_epoch"]
                    size = row["frame.len"]
                    proto = row["ip.proto"]
                    src_ip = row["ip.src"]
                    dst_ip = row["ip.dst"]
                    direction = None                # 1 for src->dst, 0 for dst->src

                    if proto == 6:  # TCP
                        sport = int(row["tcp.srcport"]) if pd.notna(row["tcp.srcport"]) else 0
                        dport = int(row["tcp.dstport"]) if pd.notna(row["tcp.dstport"]) else 0
                        syn_flag = str(row["tcp.flags.syn"]).strip() == '1'
                        fin_flag = str(row["tcp.flags.fin"]).strip() == '1'

                        # Get the connection key for bidirectional flow
                        # and determine the direction based on IP/port values
                        conn_key = get_bidirectional_key(src_ip, sport, dst_ip, dport, "TCP")

                        # Initialize flow on first sight
                        flow = flows[conn_key]
                        flow["proto"] = "TCP"
                        if flow["first_seen"] is None:
                            flow["first_seen"] = ts
                            if syn_flag:
                                flow["initiator"] = (src_ip, sport)             # src_ip, sport is the initiator of the connection

                        # Set dir. for the packet
                        if flow["initiator"]:
                            direction = 1 if (src_ip, sport) == flow["initiator"] else 0
                        else:
                            direction = 1 if (src_ip, sport) < (dst_ip, dport) else 0

                        # Append the current packet to the flow
                        flow["timestamps"].append(ts)
                        flow["sizes"].append(size)
                        flow["directions"].append(direction)

                        # Close the flow if FIN flag is set
                        if fin_flag:
                            all_flows.append({
                                "index": flow_index,
                                "connection": conn_key,
                                "timestamps": flow["timestamps"],
                                "sizes": flow["sizes"],
                                "directions": flow["directions"],
                                "label": flow["label"]
                            })
                            flow_index += 1
                            del flows[conn_key]  # Remove the flow from the dictionary

                    elif proto == 17:  # UDP
                        sport = int(row["udp.srcport"]) if pd.notna(row["udp.srcport"]) else 0
                        dport = int(row["udp.dstport"]) if pd.notna(row["udp.dstport"]) else 0

                        conn_key = get_bidirectional_key(src_ip, sport, dst_ip, dport, "UDP")
                        flow = flows[conn_key]

                        if flow["first_seen"] is None:
                            flow["first_seen"] = ts
                            flow["initiator"] = (src_ip, sport)
                        flow["proto"] = "UDP"
                        
                        # Check if the flow has been inactive for more than UDP_TIMEOUT seconds or there exists a previous packet for this connection
                        # If so, close the flow and save it to all_flows
                        last_ts = flow["last_ts"]
                        if last_ts is not None and ts - last_ts > UDP_TIMEOUT:
                            all_flows.append({
                                "index": flow_index,
                                "connection": conn_key,
                                "timestamps": flow["timestamps"],
                                "sizes": flow["sizes"],
                                "directions": flow["directions"],
                                "label": flow["label"]
                            })
                            flow_index += 1

                            # Start a new flow after closing the old one
                            flows[conn_key] = {
                                "timestamps": [],
                                "sizes": [],
                                "directions": [],
                                "label": label,
                                "last_ts": ts,
                                "proto": "UDP",
                                "first_seen": ts,
                                "initiator": (src_ip, sport)
                            }

                        # Append the current packet to the flow
                        direction = 1 if (src_ip, sport) == flow["initiator"] else 0
                        flow["timestamps"].append(ts)
                        flow["sizes"].append(size)
                        flow["directions"].append(direction)
                        
                        # Update the last timestamp for the flow
                        # used to check for inactivity in the next iteration
                        flow["last_ts"] = ts if flow["last_ts"] is None else max(flow["last_ts"], ts)

            except Exception as e:
                print(f"Failed to process {file_path}: {e}")

        # After all files of a class are processed, flush remaining flows
        for conn_key, flow_data in flows.items():
            all_flows.append({
                "index": flow_index,
                "connection": conn_key,
                "timestamps": flow_data["timestamps"],
                "sizes": flow_data["sizes"],
                "directions": flow_data["directions"],
                "label": flow_data["label"]
            })
            flow_index += 1 

        # Save flows from this file
        total_flows += len(all_flows)
        df_flows = pd.DataFrame(all_flows)
        write_header = not os.path.exists(output_file)
        df_flows.to_csv(output_file, mode='a', header=write_header, index=False)
    
        print(f"#Flows for class '{label}': {len(all_flows)}\n")
        all_flows.clear()  # Clear the list for the next class


    print(f"\n\nProcessed and found {total_flows} flows.")
    print(f"Flow data saved to '{output_file}'")

# %%
# Check if output_dir exists!
if not os.path.exists(RESULTS_DIR):
    os.makedirs(RESULTS_DIR)

# Check if grouped_classes.json already exists, 
# if so, load it into dictionary else compute it
if os.path.exists(GROUPED_JSON_FILE):
    with open(GROUPED_JSON_FILE, 'r') as f:
        grouped_files = json.load(f)
    print(f"Loaded existing groupings from '{GROUPED_JSON_FILE}'")
else:
    # If the file doesn't exist, compute the groupings
    print(f"'{GROUPED_JSON_FILE}' not found. Computing groupings for dir.: {DATA_PATH}")
    grouped_files = group_files_by_class(DATA_PATH)
# Out:
# Loaded existing groupings from 'results\grouped_classes.json'

# %%
# Print all classes(20) in the dataset
print("Classes:", list(grouped_files.keys()))
# Out:
# Classes: ['nonvpn_netflix', 'nonvpn_rdp', 'nonvpn_rsync', 'nonvpn_scp', 'nonvpn_sftp', 'nonvpn_skype-chat', 'nonvpn_ssh', 'nonvpn_vimeo', 'nonvpn_voip', 'nonvpn_youtube', 'vpn_netflix', 'vpn_rdp', 'vpn_rsync', 'vpn_scp', 'vpn_sftp', 'vpn_skype-chat', 'vpn_ssh', 'vpn_vimeo', 'vpn_voip', 'vpn_youtube']

# %%
# Now, compute flows from the grouped files or load them from the existing file
if not os.path.exists(OUTPUT_FLOWS_FILE):
    print(f"\n'{OUTPUT_FLOWS_FILE}' not found. Extracting flows from files.")
    process_files(grouped_files, DATA_PATH, OUTPUT_FLOWS_FILE)
    flows = pd.read_csv(OUTPUT_FLOWS_FILE)
else:
    print(f"\n'{OUTPUT_FLOWS_FILE}' already exists. Skipping flow extraction.")
    flows = pd.read_csv(OUTPUT_FLOWS_FILE)
    print(f"Loaded {len(flows)} flows from '{OUTPUT_FLOWS_FILE}'")
# Out:
# 'results\flows.csv' already exists. Skipping flow extraction.
# Loaded 4310 flows from 'results\flows.csv'

# %%
print("\nFlow data columns and their datatypes: ")
print(flows.info())
# Out:
# Flow data columns and their datatypes:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4310 entries, 0 to 4309
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   index       4310 non-null   int64
#  1   connection  4310 non-null   object
#  2   timestamps  4310 non-null   object
#  3   sizes       4310 non-null   object
#  4   directions  4310 non-null   object
#  5   label       4310 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 202.2+ KB
# None

# %% [markdown]
# ## Part 1: Extracting Features

# %% [markdown]
# ### Data cleaning

# %% [markdown]
# Extract the following features from the dataset:
# - Flow-level (5 features): flow duration, volume (upstream and downstream), number of packets (upstream and downstream)
# - Packet-level features (36 features): Statistics on packet inter-arrival times and packet size. These need to be computed for both upstream and downstream direction. You should compute the following statistics for each flow: mean, median, std, min, max, quantiles (25%ile, 75%iles), and deciles (10%ile, 90%ile). Compute these statistics per feature (IAT, size) and direction (upstream, downstream).
#
# **Defining Flows**: For TCP, a flow is same as connection (determined using SYN/FIN packets). You should define UDP flows using inactivity timeout, i.e., mark the end of the flow if you don't see a packet for T seconds. Use a reasonable value of T.
#
# Make sure you filter out the non-IP traffic as well as the DNS traffic from the data.

# %% [markdown]
# **Checkpoint**: Once you do that, summarize the number of flows for each application. You can extract the application name from the file name. VPN and non-VPN applications should be treated differently. You can remove classes with less than 10 instances for the next part.

# %%
def get_IAT(timestamps):
    """
    Calculate Inter-Arrival Time (IAT) from a list of timestamps.
    """
    if len(timestamps) < 2:
        return []
    return [t2 - t1 for t1, t2 in zip(timestamps[:-1], timestamps[1:])]

# %%
def compute_stats(prefix, values):
    """Compute statistical features for a given list of values."""
    if not values:
        return {f"{prefix} {stat}": 0 for stat in [
            "Mean", "Median", "Std", "Min", "Max",
            "25%ile", "75%ile", "10%ile", "90%ile"
        ]}

    return {
        f"{prefix} Mean": np.mean(values),
        f"{prefix} Median": np.median(values),
        f"{prefix} Std": np.std(values) if len(values) > 1 else 0,
        f"{prefix} Min": np.min(values),
        f"{prefix} Max": np.max(values),
        f"{prefix} 25%ile": np.percentile(values, 25),
        f"{prefix} 75%ile": np.percentile(values, 75),
        f"{prefix} 10%ile": np.percentile(values, 10),
        f"{prefix} 90%ile": np.percentile(values, 90),
    }

# %%
def compute_flow_features(df):
    """
    Compute flow-level features from the DataFrame.
    """
    flow_features = []

    for _, row in df.iterrows():
        ts_list = eval(row['timestamps'])
        size_list = eval(row['sizes'])
        dir_list = eval(row['directions'])

        # Compute flow duration (assuming timestamps are in seconds)
        flow_duration = max(ts_list) - min(ts_list) if len(ts_list) >= 2 else 0

        # Separate Fwd and Bwd
        fwd_sizes = [s for s, d in zip(size_list, dir_list) if d == 1]
        bwd_sizes = [s for s, d in zip(size_list, dir_list) if d == 0]
        fwd_ts = [t for t, d in zip(ts_list, dir_list) if d == 1]
        bwd_ts = [t for t, d in zip(ts_list, dir_list) if d == 0]

        # Compute IATs
        flow_iat = get_IAT(ts_list)
        fwd_iat = get_IAT(fwd_ts)
        bwd_iat = get_IAT(bwd_ts)

        flow_data = {
            # Basic Flow-Level Features
            'Flow Duration': flow_duration,
            'Total Fwd Packets': len(fwd_sizes),
            'Total Bwd Packets': len(bwd_sizes),
            'Total Length of Fwd Packets': sum(fwd_sizes),
            'Total Length of Bwd Packets': sum(bwd_sizes),
        }

        # Add packet size and IAT stats
        flow_data.update(compute_stats("Fwd Packet Size", fwd_sizes))
        flow_data.update(compute_stats("Bwd Packet Size", bwd_sizes))
        flow_data.update(compute_stats("Fwd IAT", fwd_iat))
        flow_data.update(compute_stats("Bwd IAT", bwd_iat))

        flow_features.append(flow_data)

    return pd.DataFrame(flow_features)

# %%
# Display instances counts for different classes:
flows["label"].value_counts()
# Out:
# label
# nonvpn_vimeo         1197
# nonvpn_skype-chat     959
# nonvpn_ssh            590
# nonvpn_scp            473
# vpn_voip              304
# nonvpn_youtube        276
# nonvpn_netflix        173
# nonvpn_sftp           113
# nonvpn_rsync          109
# nonvpn_voip            51
# nonvpn_rdp             31
# vpn_rdp                15
# vpn_ssh                 5
# vpn_rsync               4
# vpn_skype-chat          3
# vpn_youtube             2
# vpn_scp                 2
# vpn_netflix             1
# vpn_sftp                1
# vpn_vimeo               1
# Name: count, dtype: int64

# %%
# Remove classes with fewer than 10 instances
label_counts = flows["label"].value_counts()
labels_to_remove = label_counts[label_counts < 10].index
flows = flows[~flows["label"].isin(labels_to_remove)]

# Check the class distribution after filtering
print(flows["label"].value_counts())
# Out:
# label
# nonvpn_vimeo         1197
# nonvpn_skype-chat     959
# nonvpn_ssh            590
# nonvpn_scp            473
# vpn_voip              304
# nonvpn_youtube        276
# nonvpn_netflix        173
# nonvpn_sftp           113
# nonvpn_rsync          109
# nonvpn_voip            51
# nonvpn_rdp             31
# vpn_rdp                15
# Name: count, dtype: int64

# %%
# Display the number of unique classes
print("#Unique Classes:", flows["label"].nunique())
# Out:
# #Unique Classes: 12

# %%
# Overview of the data
print(flows.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4291 entries, 0 to 4307
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   index       4291 non-null   int64
#  1   connection  4291 non-null   object
#  2   timestamps  4291 non-null   object
#  3   sizes       4291 non-null   object
#  4   directions  4291 non-null   object
#  5   label       4291 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 234.7+ KB
# None

# %%
# Compute flow features
df_features = compute_flow_features(flows)
final_df = pd.concat([flows.reset_index(drop=True), df_features.reset_index(drop=True)], axis=1)

# Display count of columns in the final DataFrame
print(final_df.shape)
# Out:
# (4291, 47)

# %%
# Display list of computed features
df_features.columns
# Out:
# Index(['Flow Duration', 'Total Fwd Packets', 'Total Bwd Packets',
#        'Total Length of Fwd Packets', 'Total Length of Bwd Packets',
#        'Fwd Packet Size Mean', 'Fwd Packet Size Median', 'Fwd Packet Size Std',
#        'Fwd Packet Size Min', 'Fwd Packet Size Max', 'Fwd Packet Size 25%ile',
#        'Fwd Packet Size 75%ile', 'Fwd Packet Size 10%ile',
#        'Fwd Packet Size 90%ile', 'Bwd Packet Size Mean',
#        'Bwd Packet Size Median', 'Bwd Packet Size Std', 'Bwd Packet Size Min',
#        'Bwd Packet Size Max', 'Bwd Packet Size 25%ile',
#        'Bwd Packet Size 75%ile', 'Bwd Packet Size 10%ile',
#        'Bwd Packet Size 90%ile', 'Fwd IAT Mean', 'Fwd IAT Median',
#        'Fwd IAT Std', 'Fwd IAT Min', 'Fwd IAT Max', 'Fwd IAT 25%ile',
#        'Fwd IAT 75%ile', 'Fwd IAT 10%ile', 'Fwd IAT 90%ile', 'Bwd IAT Mean',
#        'Bwd IAT Median', 'Bwd IAT Std', 'Bwd IAT Min', 'Bwd IAT Max',
#        'Bwd IAT 25%ile', 'Bwd IAT 75%ile', 'Bwd IAT 10%ile', 'Bwd IAT 90%ile'],
#       dtype='object')

# %%
# Display cols of the final DataFrame
final_df.columns
# Out:
# Index(['index', 'connection', 'timestamps', 'sizes', 'directions', 'label',
#        'Flow Duration', 'Total Fwd Packets', 'Total Bwd Packets',
#        'Total Length of Fwd Packets', 'Total Length of Bwd Packets',
#        'Fwd Packet Size Mean', 'Fwd Packet Size Median', 'Fwd Packet Size Std',
#        'Fwd Packet Size Min', 'Fwd Packet Size Max', 'Fwd Packet Size 25%ile',
#        'Fwd Packet Size 75%ile', 'Fwd Packet Size 10%ile',
#        'Fwd Packet Size 90%ile', 'Bwd Packet Size Mean',
#        'Bwd Packet Size Median', 'Bwd Packet Size Std', 'Bwd Packet Size Min',
#        'Bwd Packet Size Max', 'Bwd Packet Size 25%ile',
#        'Bwd Packet Size 75%ile', 'Bwd Packet Size 10%ile',
#        'Bwd Packet Size 90%ile', 'Fwd IAT Mean', 'Fwd IAT Median',
#        'Fwd IAT Std', 'Fwd IAT Min', 'Fwd IAT Max', 'Fwd IAT 25%ile',
#        'Fwd IAT 75%ile', 'Fwd IAT 10%ile', 'Fwd IAT 90%ile', 'Bwd IAT Mean',
#        'Bwd IAT Median', 'Bwd IAT Std', 'Bwd IAT Min', 'Bwd IAT Max',
#        'Bwd IAT 25%ile', 'Bwd IAT 75%ile', 'Bwd IAT 10%ile', 'Bwd IAT 90%ile'],
#       dtype='object')

# %%
# Overview of the final DataFrame
final_df.describe().T
# Out:
#                               count          mean           std  \
# index                        4291.0  2.147208e+03  1.240799e+03
# Flow Duration                4291.0  4.530456e+03  9.516232e+04
# Total Fwd Packets            4291.0  2.670252e+03  2.338483e+04
# Total Bwd Packets            4291.0  2.822294e+03  2.419535e+04
# Total Length of Fwd Packets  4291.0  2.200466e+06  2.388576e+07
# Total Length of Bwd Packets  4291.0  2.606432e+06  2.634235e+07
# Fwd Packet Size Mean         4291.0  2.572202e+02  2.675455e+02
# Fwd Packet Size Median       4291.0  1.735337e+02  3.012959e+02
# Fwd Packet Size Std          4291.0  2.140014e+02  1.626700e+02
# Fwd Packet Size Min          4291.0  8.564484e+01  1.403746e+02
# Fwd Packet Size Max          4291.0  9.410098e+02  4.840822e+02
# Fwd Packet Size 25%ile       4291.0  1.448528e+02  2.927353e+02
# Fwd Packet Size 75%ile       4291.0  2.651899e+02  3.171404e+02
# Fwd Packet Size 10%ile       4291.0  1.246743e+02  2.562065e+02
# Fwd Packet Size 90%ile       4291.0  4.920408e+02  4.093760e+02
# Bwd Packet Size Mean         4291.0  3.449012e+02  3.627462e+02
# Bwd Packet Size Median       4291.0  2.569191e+02  4.151123e+02
# Bwd Packet Size Std          4291.0  2.585321e+02  2.108738e+02
# Bwd Packet Size Min          4291.0  5.871895e+01  9.804292e+01
# Bwd Packet Size Max          4291.0  9.189876e+02  5.564989e+02
# Bwd Packet Size 25%ile       4291.0  1.859284e+02  3.820850e+02
# Bwd Packet Size 75%ile       4291.0  4.497336e+02  5.029493e+02
# Bwd Packet Size 10%ile       4291.0  1.402422e+02  3.127003e+02
# Bwd Packet Size 90%ile       4291.0  6.568899e+02  5.468661e+02
# Fwd IAT Mean                 4291.0  1.444737e+02  5.339457e+03
# Fwd IAT Median               4291.0  6.137350e+01  3.505504e+03
# Fwd IAT Std                  4291.0  2.279976e+02  1.157002e+04
# Fwd IAT Min                  4291.0 -2.392566e+01  6.566759e+03
# Fwd IAT Max                  4291.0  2.025610e+03  6.668250e+04
# Fwd IAT 25%ile               4291.0  6.123929e+01  3.505506e+03
# Fwd IAT 75%ile               4291.0  6.307243e+01  3.505502e+03
# Fwd IAT 10%ile               4291.0  6.118385e+01  3.505507e+03
# Fwd IAT 90%ile               4291.0  1.988391e+02  6.935743e+03
# Bwd IAT Mean                 4291.0 -6.964459e+01  5.004878e+03
# Bwd IAT Median               4291.0 -7.625917e+01  5.002315e+03
# Bwd IAT Std                  4291.0  5.881345e+01  2.224039e+03
# Bwd IAT Min                  4291.0 -1.611122e+02  7.472182e+03
# Bwd IAT Max                  4291.0  1.677354e+03  5.682448e+04
# Bwd IAT 25%ile               4291.0 -7.633499e+01  5.002314e+03
# Bwd IAT 75%ile               4291.0 -7.353801e+01  5.002398e+03
# Bwd IAT 10%ile               4291.0 -7.635029e+01  5.002313e+03
# Bwd IAT 90%ile               4291.0 -6.603995e+01  5.002707e+03
#
#                                        min           25%          50%  \
# index                             1.000000  1.073500e+03  2146.000000
# Flow Duration                     0.000000  3.489100e-01     9.000883
# Total Fwd Packets                 0.000000  8.000000e+00    14.000000
# Total Bwd Packets                 0.000000  6.000000e+00    11.000000
# Total Length of Fwd Packets       0.000000  1.330000e+03  3499.000000
# Total Length of Bwd Packets       0.000000  8.725000e+02  4257.000000
# Fwd Packet Size Mean              0.000000  1.231561e+02   176.600000
# Fwd Packet Size Median            0.000000  5.200000e+01    67.500000
# Fwd Packet Size Std               0.000000  7.314732e+01   199.407811
# Fwd Packet Size Min               0.000000  5.200000e+01    52.000000
# Fwd Packet Size Max               0.000000  5.690000e+02  1224.000000
# Fwd Packet Size 25%ile            0.000000  5.200000e+01    52.000000
# Fwd Packet Size 75%ile            0.000000  9.925000e+01   156.500000
# Fwd Packet Size 10%ile            0.000000  5.200000e+01    52.000000
# Fwd Packet Size 90%ile            0.000000  1.640000e+02   347.500000
# Bwd Packet Size Mean              0.000000  1.206135e+02   209.000000
# Bwd Packet Size Median            0.000000  5.200000e+01    88.000000
# Bwd Packet Size Std               0.000000  5.964040e+01   225.289792
# Bwd Packet Size Min               0.000000  4.000000e+01    52.000000
# Bwd Packet Size Max               0.000000  3.080000e+02  1332.000000
# Bwd Packet Size 25%ile            0.000000  5.200000e+01    52.000000
# Bwd Packet Size 75%ile            0.000000  9.700000e+01   205.000000
# Bwd Packet Size 10%ile            0.000000  4.360000e+01    52.000000
# Bwd Packet Size 90%ile            0.000000  1.985000e+02   403.200000
# Fwd IAT Mean                     -0.043694  6.956084e-03     0.394812
# Fwd IAT Median                    0.000000  1.785755e-04     0.001253
# Fwd IAT Std                       0.000000  2.104383e-02     1.142132
# Fwd IAT Min                 -363677.341150  2.098083e-05     0.000026
# Fwd IAT Max                       0.000000  2.141155e-01     5.002836
# Fwd IAT 25%ile                    0.000000  4.220009e-05     0.000353
# Fwd IAT 75%ile                    0.000000  7.388592e-04     0.013564
# Fwd IAT 10%ile                    0.000000  2.884865e-05     0.000055
# Fwd IAT 90%ile                    0.000000  1.730275e-03     0.108405
# Bwd IAT Mean                -327680.149217  1.076522e-03     0.122100
# Bwd IAT Median              -327680.149217  1.406670e-05     0.000866
# Bwd IAT Std                       0.000000  2.741451e-03     0.383055
# Bwd IAT Min                 -363679.595183  9.536743e-07     0.000004
# Bwd IAT Max                 -327680.149217  4.081142e-02     2.015711
# Bwd IAT 25%ile              -327680.149217  9.059906e-06     0.000466
# Bwd IAT 75%ile              -327680.149217  1.021624e-04     0.010234
# Bwd IAT 10%ile              -327680.149217  2.336502e-06     0.000033
# Bwd IAT 90%ile              -327680.149217  4.494429e-04     0.118579
#
#                                      75%           max
# index                        3218.500000  4.308000e+03
# Flow Duration                  37.824020  2.612537e+06
# Total Fwd Packets              41.000000  9.201140e+05
# Total Bwd Packets              36.000000  1.082232e+06
# Total Length of Fwd Packets  6193.500000  6.739421e+08
# Total Length of Bwd Packets  8858.000000  1.152870e+09
# Fwd Packet Size Mean          305.111111  1.514000e+03
# Fwd Packet Size Median        103.000000  1.514000e+03
# Fwd Packet Size Std           345.483414  6.598711e+02
# Fwd Packet Size Min            52.000000  1.514000e+03
# Fwd Packet Size Max          1378.000000  1.514000e+03
# Fwd Packet Size 25%ile         66.000000  1.514000e+03
# Fwd Packet Size 75%ile        300.000000  1.514000e+03
# Fwd Packet Size 10%ile         52.000000  1.514000e+03
# Fwd Packet Size 90%ile        673.450000  1.514000e+03
# Bwd Packet Size Mean          445.176471  1.514000e+03
# Bwd Packet Size Median        191.000000  1.514000e+03
# Bwd Packet Size Std           467.821706  6.597611e+02
# Bwd Packet Size Min            52.000000  1.514000e+03
# Bwd Packet Size Max          1378.000000  1.514000e+03
# Bwd Packet Size 25%ile         75.500000  1.514000e+03
# Bwd Packet Size 75%ile        678.125000  1.514000e+03
# Bwd Packet Size 10%ile         52.000000  1.514000e+03
# Bwd Packet Size 90%ile       1378.000000  1.514000e+03
# Fwd IAT Mean                    2.445792  2.431982e+05
# Fwd IAT Median                  0.005064  2.272872e+05
# Fwd IAT Std                     2.855558  7.295883e+05
# Fwd IAT Min                     0.000054  2.272872e+05
# Fwd IAT Max                    14.575433  2.610738e+06
# Fwd IAT 25%ile                  0.000516  2.272872e+05
# Fwd IAT 75%ile                  0.059575  2.272872e+05
# Fwd IAT 10%ile                  0.000260  2.272872e+05
# Fwd IAT 90%ile                  4.001888  3.076425e+05
# Bwd IAT Mean                    1.201514  7.222482e+03
# Bwd IAT Median                  0.009881  5.358346e+01
# Bwd IAT Std                     3.364089  1.340446e+05
# Bwd IAT Min                     0.000056  8.070096e+00
# Bwd IAT Max                    10.922530  2.525610e+06
# Bwd IAT 25%ile                  0.001147  2.679295e+01
# Bwd IAT 75%ile                  0.051538  3.202828e+02
# Bwd IAT 10%ile                  0.000436  1.071865e+01
# Bwd IAT 90%ile                  3.320143  5.426950e+02

# %%
# Check for NaN values in the final DataFrame
data_tmp = final_df.copy()

# Replace infinities with NaN and drop rows with any NaNs in numeric cols
numeric_cols = data_tmp.select_dtypes(include=[np.number]).columns
data_tmp[numeric_cols] = data_tmp[numeric_cols].replace([np.inf, -np.inf], np.nan)
data_tmp.dropna(inplace=True)

# %% [markdown]
# ## Part 2: Application Classification

# %% [markdown]
# ### Prepare your data

# %% [markdown]
# ### Train Your Model
# - Select a model of your choice.
# - Train the model using the training data.

# %% [markdown]
# ### Tune Your Model
# Perform hyperparameter tuning to find optimal parameters for your model.

# %% [markdown]
# ### Evaluate Your Model
#
# **Checkpoint**: Evaluate your model accuracy according to the following metrics using 10-fold cross validation:
#
# - Accuracy
# - F1 Score
# - Confusion Matrix
# - ROC/AUC
#
# Your code should evaluate these metrics in separate cells

# %%
# Encode the labels
le = LabelEncoder()
data_tmp["label_encoded"] = le.fit_transform(data_tmp["label"])

# %%
# Extract features and labels
feature_cols = list(df_features.columns)
features = data_tmp[feature_cols]
labels = data_tmp["label_encoded"]

# Check the shapes of features and labels
print("Features shape:", features.shape)
print("Labels shape:", labels.shape)
# Out:
# Features shape: (4291, 41)
# Labels shape: (4291,)

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.3, random_state=42)
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
# Simple Random Forest Classifier
rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)

# Evaluate the model
y_pred_simple = rf.predict(X_test)
print(classification_report(y_test, y_pred_simple, target_names=le.classes_))
# Out:
#                    precision    recall  f1-score   support
#
#    nonvpn_netflix       0.87      0.62      0.73        53
#        nonvpn_rdp       1.00      0.85      0.92        13
#      nonvpn_rsync       0.67      0.14      0.23        43
#        nonvpn_scp       0.76      0.89      0.82       137
#       nonvpn_sftp       0.40      0.51      0.45        37
# nonvpn_skype-chat       1.00      1.00      1.00       297
#        nonvpn_ssh       0.99      1.00      1.00       179
#      nonvpn_vimeo       0.94      0.98      0.96       338
#       nonvpn_voip       0.93      1.00      0.96        13
#    nonvpn_youtube       0.96      0.95      0.96        83
#           vpn_rdp       0.67      0.80      0.73         5
#          vpn_voip       1.00      0.99      0.99        90
#
#          accuracy                           0.92      1288
#         macro avg       0.85      0.81      0.81      1288
#      weighted avg       0.92      0.92      0.91      1288

# %%
print("y_pred shape       : ", y_pred_simple.shape)                         # Predicted labels for test data
print()
print(f"Accuracy: {accuracy_score(y_test, y_pred_simple):.2f}")
# Out:
# y_pred shape       :  (1288,)
#
# Accuracy: 0.92

# %%
model = "simple RF"
cm = confusion_matrix(y_test, y_pred_simple)
plt.figure(figsize=(8, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=le.classes_, yticklabels=le.classes_)
plt.title(f"Confusion Matrix for {model}")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
# Mapping encoded labels to class names
label_mapping_inv = {i: label for i, label in enumerate(le.classes_)}

# class distribution
unique_actual, counts_actual = np.unique(y_test, return_counts=True)    # Actual class distribution
unique_pred, counts_pred = np.unique(y_pred_simple, return_counts=True) # Predicted class distribution

# Convert numbers to class labels
actual_labels = [label_mapping_inv[i] for i in unique_actual]
predicted_labels = [label_mapping_inv[i] for i in unique_pred]

# Ensure all labels are present (even if missing in predictions)
all_labels = sorted(set(actual_labels) | set(predicted_labels), key=lambda x: x if x in label_mapping_inv else float('inf'))

# Convert to dictionary for alignment
actual_counts_dict = dict(zip(actual_labels, counts_actual))
predicted_counts_dict = dict(zip(predicted_labels, counts_pred))

# Fill missing classes with zero count
actual_counts = [actual_counts_dict.get(label, 0) for label in all_labels]
predicted_counts = [predicted_counts_dict.get(label, 0) for label in all_labels]

# Count correctly predicted samples for each class (True Positives)
true_positives = {label: 0 for label in all_labels}  # Initialize all as 0

for actual, pred in zip(y_test, y_pred_simple):
    if actual == pred:  # Correct prediction
        class_label = label_mapping_inv[actual]
        true_positives[class_label] += 1

# Convert true positives to a list for plotting
true_positive_counts = [true_positives.get(label, 0) for label in all_labels]

# Bar width and positions
x = np.arange(len(all_labels))  # Positions for bars
width = 0.3  # Width of bars

# Plot
plt.figure(figsize=(12,6))
bars1 = plt.bar(x - width, predicted_counts, width, label="Predicted Count", color="black", alpha=0.7)
bars2 = plt.bar(x, true_positive_counts, width, label="Correctly Predicted Count", color="blue", alpha=0.7)
bars3 = plt.bar(x + width, actual_counts, width, label="Actual Count", color="red", alpha=0.7)

# Add text labels on bars
for bars in [bars1, bars2, bars3]:
    for bar in bars:
        height = bar.get_height()
        plt.text(bar.get_x() + bar.get_width()/2, height, f'{height}', ha='center', va='bottom', fontsize=7, fontweight='bold')

# Labels and Title
plt.xlabel('Class Labels')
plt.ylabel('Count')
plt.title(f'Actual vs Predicted vs Correctly Predicted Class Distribution for Test Data Sized : {len(y_test)} samples')
plt.xticks(ticks=x, labels=all_labels, rotation=45, ha='right')  # Rotate x-labels for better readability
plt.legend()
plt.show()

# %%
# Cross-validation for Random Forest
rf_cv = RandomForestClassifier(n_estimators=100, random_state=42)
rf_cv.fit(X_train, y_train)

# Perform 10-fold cross-validation and get accuracy scores
cv_scores = cross_val_score(rf_cv, features, labels, cv=10, scoring='accuracy')

# Print the accuracy for each fold and the average accuracy
print(f"Cross-validation accuracies: {cv_scores}")
print(f"\nAverage cross-validation accuracy: {np.mean(cv_scores):.2f}")
# Out:
# Cross-validation accuracies: [0.78837209 0.88578089 0.8974359  0.91608392 0.91841492 0.92540793
#  0.92074592 0.94405594 0.95337995 0.95337995]
#
# Average cross-validation accuracy: 0.91

# %%
# Binarize the labels for multi-class ROC (One-vs-Rest)
y_test_bin = label_binarize(y_test, classes=np.unique(y_test))  # Binarize the actual test labels
y_pred_prob = rf_cv.predict_proba(X_test)  # Get predicted probabilities for each class

# Plot ROC curve for each class
plt.figure(figsize=(10, 8))
for i in range(y_test_bin.shape[1]):
    fpr, tpr, _ = roc_curve(y_test_bin[:, i], y_pred_prob[:, i])
    roc_auc = auc(fpr, tpr)  # Calculate AUC for the class
    plt.plot(fpr, tpr, label=f'{le.classes_[i]} (AUC = {roc_auc:.2f})')

# Plotting the ROC curve (diagonal line)
plt.plot([0, 1], [0, 1], color='navy', linestyle='--')

# Labels and Title
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# ## Part 3: Comparison with a deep learning-based model

# %% [markdown]
# In this part, you will compare your model with the DeepPacket model in terms of accuracy, explainability, and system cost. You can download a pre-trained DeepPacket model (pre-trained on the same dataset) using this [link](https://github.com/munhouiani/Deep-Packet). There is also featurized data available on the same link which you can use directly.
#
# Specifically, you should compare your trained model with the DeepPacket model in the following terms:
# - **Accuracy**: Compare the accuracy of the two models. Are there classes where one model is doing significantly better than the other?
# - **Explainability**: conduct an explainability analysis of the two models. For instance, you could do a simple feature importance analysis if you are using decision tree for the first model. For DeepPacket, please use TRUSTEE to figure out the most important features and check which part of the packet (payload, TCP, TCP options etc.) do these correspond.
# - **System cost**: Analyze the runtime complexity of the model. Do this only for testing and NOT training.

# %% [markdown]
# ## Report here
# Write your report here

# %%
"""
    Accuracy Comparison:
    1. Simple RF: 
        - 0.92
    2. RF with 10-fold CV: 
        - 0.91
    3. Deep Packet: 
        - 0.95 (not shown here)

        
    System cost:
    1. Simple RF:
        - CPU is sufficient.
        - Easy to parallelize across trees
    2. Deep Packet:
        - GPU is required for training and inference.
        - Parallelism via GPU acceleration (Tensor cores)

        
    Runtime-Complexity:
    1. Simple RF: 
        - Training :  O(n_trees * n_samples * log n_features)
        - Testing  :  O(n_trees * log n_features)
    2. Deep Packet: 
        - Training :  O(n_epochs * n_samples * d_layers)
        - Testing  :  O(#conv_ops + #dense_ops)

"""

# %%
# Plot for Feature Importance - RF model
importances = rf.feature_importances_
feature_names = features.columns

plt.figure(figsize=(6, 14))
bars = plt.barh(feature_names, importances, color='teal')
plt.xlabel("Importance")
plt.ylabel("Feature")
plt.title("Feature Importance")
for bar in bars:
    plt.text(bar.get_width() / 2,                               # X position (center of the bar)
             bar.get_y() + bar.get_height() / 2,                # Y position (center)
             f'{bar.get_width():.2f}',                          # Display importance value
             ha='center', va='center', fontsize=10, color='white')  
    
plt.show()

# %%
from trustee import ClassificationTrustee

# Initialize and fit the ClassificationTrustee
trustee = ClassificationTrustee(expert=rf)
trustee.fit(X_train, y_train, num_iter=50, num_stability_iter=10, samples_size=0.3, verbose=True)

# Get the best student model and its explanation
dt, pruned_dt, agreement, reward = trustee.explain()
dt_y_pred = dt.predict(X_test)
# Out:
# Initializing training dataset using RandomForestClassifier(random_state=42) as expert model
# Expert model score: 0.8983692423329733
# Initializing Trustee outer-loop with 10 iterations
# ########## Outer-loop Iteration 0/10 ##########
# Initializing Trustee inner-loop with 10 iterations
# ########## Inner-loop Iteration 0/50 ##########
# Sampling 630 points from training dataset with (2102, 2102) entries
# Student model 0-0 trained with depth 14 and 52 leaves:
# Student model score: 0.8009767484686799
# Student model 0-0 fidelity: 0.8009767484686799
# ########## Inner-loop Iteration 1/50 ##########
# Sampling 630 points from training dataset with (2291, 2291) entries
# Student model 0-1 trained with depth 11 and 42 leaves:
# Student model score: 0.6858200709649984
# Student model 0-1 fidelity: 0.6858200709649984
# ########## Inner-loop Iteration 2/50 ##########
# Sampling 630 points from training dataset with (2480, 2480) entries
# Student model 0-2 trained with depth 11 and 44 leaves:
# Student model score: 0.7593170861739253
# Student model 0-2 fidelity: 0.7593170861739253
# ########## Inner-loop Iteration 3/50 ##########
# Sampling 630 points from training dataset with (2669, 2669) entries
# Student model 0-3 trained with depth 10 and 43 leaves:
# Student model score: 0.7732069828835523
# Student model 0-3 fidelity: 0.7732069828835523
# ########## Inner-loop Iteration 4/50 ##########
# Sampling 630 points from training dataset with (2858, 2858) entries
# Student model 0-4 trained with depth 10 and 41 leaves:
# Student model score: 0.7987772710489114
# Student model 0-4 fidelity: 0.7987772710489114
# ########## Inner-loop Iteration 5/50 ##########
# Sampling 630 points from training dataset with (3047, 3047) entries
# Student model 0-5 trained with depth 14 and 46 leaves:
# Student model score: 0.8927633254258641
# Student model 0-5 fidelity: 0.8927633254258641
# ########## Inner-loop Iteration 6/50 ##########
# Sampling 630 points from training dataset with (3236, 3236) entries
# Student model 0-6 trained with depth 11 and 46 leaves:
# Student model score: 0.8671288143381165
# Student model 0-6 fidelity: 0.8671288143381165
# ########## Inner-loop Iteration 7/50 ##########
# Sampling 630 points from training dataset with (3425, 3425) entries
# Student model 0-7 trained with depth 9 and 32 leaves:
# Student model score: 0.7636784261063689
# Student model 0-7 fidelity: 0.7636784261063689
# ########## Inner-loop Iteration 8/50 ##########
# Sampling 630 points from training dataset with (3614, 3614) entries
# Student model 0-8 trained with depth 11 and 43 leaves:
# Student model score: 0.7191288137699621
# Student model 0-8 fidelity: 0.7191288137699621
# ########## Inner-loop Iteration 9/50 ##########
# Sampling 630 points from training dataset with (3803, 3803) entries
# Student model 0-9 trained with depth 11 and 47 leaves:
# Student model score: 0.8047379765484021
# Student model 0-9 fidelity: 0.8047379765484021
# ########## Inner-loop Iteration 10/50 ##########
# Sampling 630 points from training dataset with (3992, 3992) entries
# Student model 0-10 trained with depth 12 and 48 leaves:
# Student model score: 0.7958023564192861
# Student model 0-10 fidelity: 0.7958023564192861
# ########## Inner-loop Iteration 11/50 ##########
# Sampling 630 points from training dataset with (4181, 4181) entries
# Student model 0-11 trained with depth 12 and 53 leaves:
# Student model score: 0.7974664881116494
# Student model 0-11 fidelity: 0.7974664881116494
# ########## Inner-loop Iteration 12/50 ##########
# Sampling 630 points from training dataset with (4370, 4370) entries
# Student model 0-12 trained with depth 10 and 49 leaves:
# Student model score: 0.7547191575404743
# Student model 0-12 fidelity: 0.7547191575404743
# ########## Inner-loop Iteration 13/50 ##########
# Sampling 630 points from training dataset with (4559, 4559) entries
# Student model 0-13 trained with depth 12 and 46 leaves:
# Student model score: 0.7800917561889271
# Student model 0-13 fidelity: 0.7800917561889271
# ########## Inner-loop Iteration 14/50 ##########
# Sampling 630 points from training dataset with (4748, 4748) entries
# Student model 0-14 trained with depth 11 and 44 leaves:
# Student model score: 0.7399322861280332
# Student model 0-14 fidelity: 0.7399322861280332
# ########## Inner-loop Iteration 15/50 ##########
# Sampling 630 points from training dataset with (4937, 4937) entries
# Student model 0-15 trained with depth 10 and 41 leaves:
# Student model score: 0.5821680209531872
# Student model 0-15 fidelity: 0.5821680209531872
# ########## Inner-loop Iteration 16/50 ##########
# Sampling 630 points from training dataset with (5126, 5126) entries
# Student model 0-16 trained with depth 13 and 46 leaves:
# Student model score: 0.7657152574597673
# Student model 0-16 fidelity: 0.7657152574597673
# ########## Inner-loop Iteration 17/50 ##########
# Sampling 630 points from training dataset with (5315, 5315) entries
# Student model 0-17 trained with depth 10 and 50 leaves:
# Student model score: 0.7657651887711574
# Student model 0-17 fidelity: 0.7657651887711574
# ########## Inner-loop Iteration 18/50 ##########
# Sampling 630 points from training dataset with (5504, 5504) entries
# Student model 0-18 trained with depth 9 and 43 leaves:
# Student model score: 0.8353468287501272
# Student model 0-18 fidelity: 0.8353468287501272
# ########## Inner-loop Iteration 19/50 ##########
# Sampling 630 points from training dataset with (5693, 5693) entries
# Student model 0-19 trained with depth 11 and 49 leaves:
# Student model score: 0.8089100507888919
# Student model 0-19 fidelity: 0.8089100507888919
# ########## Inner-loop Iteration 20/50 ##########
# Sampling 630 points from training dataset with (5882, 5882) entries
# Student model 0-20 trained with depth 11 and 50 leaves:
# Student model score: 0.7488834021728757
# Student model 0-20 fidelity: 0.7488834021728757
# ########## Inner-loop Iteration 21/50 ##########
# Sampling 630 points from training dataset with (6071, 6071) entries
# Student model 0-21 trained with depth 10 and 42 leaves:
# Student model score: 0.7031151561356177
# Student model 0-21 fidelity: 0.7031151561356177
# ########## Inner-loop Iteration 22/50 ##########
# Sampling 630 points from training dataset with (6260, 6260) entries
# Student model 0-22 trained with depth 11 and 46 leaves:
# Student model score: 0.7495954987183057
# Student model 0-22 fidelity: 0.7495954987183057
# ########## Inner-loop Iteration 23/50 ##########
# Sampling 630 points from training dataset with (6449, 6449) entries
# Student model 0-23 trained with depth 11 and 46 leaves:
# Student model score: 0.7141891262071313
# Student model 0-23 fidelity: 0.7141891262071313
# ########## Inner-loop Iteration 24/50 ##########
# Sampling 630 points from training dataset with (6638, 6638) entries
# Student model 0-24 trained with depth 11 and 53 leaves:
# Student model score: 0.8176832377628486
# Student model 0-24 fidelity: 0.8176832377628486
# ########## Inner-loop Iteration 25/50 ##########
# Sampling 630 points from training dataset with (6827, 6827) entries
# Student model 0-25 trained with depth 11 and 49 leaves:
# Student model score: 0.8557709728065765
# Student model 0-25 fidelity: 0.8557709728065765
# ########## Inner-loop Iteration 26/50 ##########
# Sampling 630 points from training dataset with (7016, 7016) entries
# Student model 0-26 trained with depth 11 and 43 leaves:
# Student model score: 0.7108412059188277
# Student model 0-26 fidelity: 0.7108412059188277
# ########## Inner-loop Iteration 27/50 ##########
# Sampling 630 points from training dataset with (7205, 7205) entries
# Student model 0-27 trained with depth 12 and 41 leaves:
# Student model score: 0.890597165266439
# Student model 0-27 fidelity: 0.890597165266439
# ########## Inner-loop Iteration 28/50 ##########
# Sampling 630 points from training dataset with (7394, 7394) entries
# Student model 0-28 trained with depth 13 and 44 leaves:
# Student model score: 0.7174964155675828
# Student model 0-28 fidelity: 0.7174964155675828
# ########## Inner-loop Iteration 29/50 ##########
# Sampling 630 points from training dataset with (7583, 7583) entries
# Student model 0-29 trained with depth 11 and 45 leaves:
# Student model score: 0.7078299130129155
# Student model 0-29 fidelity: 0.7078299130129155
# ########## Inner-loop Iteration 30/50 ##########
# Sampling 630 points from training dataset with (7772, 7772) entries
# Student model 0-30 trained with depth 10 and 42 leaves:
# Student model score: 0.7787922170028074
# Student model 0-30 fidelity: 0.7787922170028074
# ########## Inner-loop Iteration 31/50 ##########
# Sampling 630 points from training dataset with (7961, 7961) entries
# Student model 0-31 trained with depth 11 and 51 leaves:
# Student model score: 0.7066944749637861
# Student model 0-31 fidelity: 0.7066944749637861
# ########## Inner-loop Iteration 32/50 ##########
# Sampling 630 points from training dataset with (8150, 8150) entries
# Student model 0-32 trained with depth 13 and 41 leaves:
# Student model score: 0.7573406977496042
# Student model 0-32 fidelity: 0.7573406977496042
# ########## Inner-loop Iteration 33/50 ##########
# Sampling 630 points from training dataset with (8339, 8339) entries
# Student model 0-33 trained with depth 11 and 56 leaves:
# Student model score: 0.7761165188128317
# Student model 0-33 fidelity: 0.7761165188128317
# ########## Inner-loop Iteration 34/50 ##########
# Sampling 630 points from training dataset with (8528, 8528) entries
# Student model 0-34 trained with depth 14 and 46 leaves:
# Student model score: 0.8013153358986692
# Student model 0-34 fidelity: 0.8013153358986692
# ########## Inner-loop Iteration 35/50 ##########
# Sampling 630 points from training dataset with (8717, 8717) entries
# Student model 0-35 trained with depth 11 and 46 leaves:
# Student model score: 0.8100193650398849
# Student model 0-35 fidelity: 0.8100193650398849
# ########## Inner-loop Iteration 36/50 ##########
# Sampling 630 points from training dataset with (8906, 8906) entries
# Student model 0-36 trained with depth 12 and 43 leaves:
# Student model score: 0.7928385854292663
# Student model 0-36 fidelity: 0.7928385854292663
# ########## Inner-loop Iteration 37/50 ##########
# Sampling 630 points from training dataset with (9095, 9095) entries
# Student model 0-37 trained with depth 11 and 47 leaves:
# Student model score: 0.7764980596815202
# Student model 0-37 fidelity: 0.7764980596815202
# ########## Inner-loop Iteration 38/50 ##########
# Sampling 630 points from training dataset with (9284, 9284) entries
# Student model 0-38 trained with depth 10 and 52 leaves:
# Student model score: 0.7156599079606618
# Student model 0-38 fidelity: 0.7156599079606618
# ########## Inner-loop Iteration 39/50 ##########
# Sampling 630 points from training dataset with (9473, 9473) entries
# Student model 0-39 trained with depth 11 and 48 leaves:
# Student model score: 0.8434141189424839
# Student model 0-39 fidelity: 0.8434141189424839
# ########## Inner-loop Iteration 40/50 ##########
# Sampling 630 points from training dataset with (9662, 9662) entries
# Student model 0-40 trained with depth 11 and 53 leaves:
# Student model score: 0.8220581848077311
# Student model 0-40 fidelity: 0.8220581848077311
# ########## Inner-loop Iteration 41/50 ##########
# Sampling 630 points from training dataset with (9851, 9851) entries
# Student model 0-41 trained with depth 12 and 44 leaves:
# Student model score: 0.7648090356732758
# Student model 0-41 fidelity: 0.7648090356732758
# ########## Inner-loop Iteration 42/50 ##########
# Sampling 630 points from training dataset with (10040, 10040) entries
# Student model 0-42 trained with depth 14 and 48 leaves:
# Student model score: 0.6830932923476783
# Student model 0-42 fidelity: 0.6830932923476783
# ########## Inner-loop Iteration 43/50 ##########
# Sampling 630 points from training dataset with (10229, 10229) entries
# Student model 0-43 trained with depth 11 and 50 leaves:
# Student model score: 0.7647808029601185
# Student model 0-43 fidelity: 0.7647808029601185
# ########## Inner-loop Iteration 44/50 ##########
# Sampling 630 points from training dataset with (10418, 10418) entries
# Student model 0-44 trained with depth 12 and 44 leaves:
# Student model score: 0.7723069483648175
# Student model 0-44 fidelity: 0.7723069483648175
# ########## Inner-loop Iteration 45/50 ##########
# Sampling 630 points from training dataset with (10607, 10607) entries
# Student model 0-45 trained with depth 12 and 52 leaves:
# Student model score: 0.8124957830586714
# Student model 0-45 fidelity: 0.8124957830586714
# ########## Inner-loop Iteration 46/50 ##########
# Sampling 630 points from training dataset with (10796, 10796) entries
# Student model 0-46 trained with depth 10 and 38 leaves:
# Student model score: 0.7908965269838439
# Student model 0-46 fidelity: 0.7908965269838439
# ########## Inner-loop Iteration 47/50 ##########
# Sampling 630 points from training dataset with (10985, 10985) entries
# Student model 0-47 trained with depth 16 and 49 leaves:
# Student model score: 0.7196492901038356
# Student model 0-47 fidelity: 0.7196492901038356
# ########## Inner-loop Iteration 48/50 ##########
# Sampling 630 points from training dataset with (11174, 11174) entries
# Student model 0-48 trained with depth 10 and 45 leaves:
# Student model score: 0.7652980297144473
# Student model 0-48 fidelity: 0.7652980297144473
# ########## Inner-loop Iteration 49/50 ##########
# Sampling 630 points from training dataset with (11363, 11363) entries
# Student model 0-49 trained with depth 12 and 50 leaves:
# Student model score: 0.8787278376993063
# Student model 0-49 fidelity: 0.8787278376993063
# ########## Outer-loop Iteration 1/10 ##########
# Initializing Trustee inner-loop with 10 iterations
# ########## Inner-loop Iteration 0/50 ##########
# Sampling 630 points from training dataset with (11552, 11552) entries
# Student model 1-0 trained with depth 11 and 47 leaves:
# Student model score: 0.8396487696826268
# Student model 1-0 fidelity: 0.8396487696826268
# ########## Inner-loop Iteration 1/50 ##########
# Sampling 630 points from training dataset with (11741, 11741) entries
# Student model 1-1 trained with depth 11 and 44 leaves:
# Student model score: 0.8204870853162781
# Student model 1-1 fidelity: 0.8204870853162781
# ########## Inner-loop Iteration 2/50 ##########
# Sampling 630 points from training dataset with (11930, 11930) entries
# Student model 1-2 trained with depth 10 and 44 leaves:
# Student model score: 0.8330084960110834
# Student model 1-2 fidelity: 0.8330084960110834
# ########## Inner-loop Iteration 3/50 ##########
# Sampling 630 points from training dataset with (12119, 12119) entries
# Student model 1-3 trained with depth 10 and 42 leaves:
# Student model score: 0.8216897617632911
# Student model 1-3 fidelity: 0.8216897617632911
# ########## Inner-loop Iteration 4/50 ##########
# Sampling 630 points from training dataset with (12308, 12308) entries
# Student model 1-4 trained with depth 11 and 45 leaves:
# Student model score: 0.6561102864821975
# Student model 1-4 fidelity: 0.6561102864821975
# ########## Inner-loop Iteration 5/50 ##########
# Sampling 630 points from training dataset with (12497, 12497) entries
# Student model 1-5 trained with depth 14 and 47 leaves:
# Student model score: 0.6657600424724633
# Student model 1-5 fidelity: 0.6657600424724633
# ########## Inner-loop Iteration 6/50 ##########
# Sampling 630 points from training dataset with (12686, 12686) entries
# Student model 1-6 trained with depth 11 and 42 leaves:
# Student model score: 0.7458037245177802
# Student model 1-6 fidelity: 0.7458037245177802
# ########## Inner-loop Iteration 7/50 ##########
# Sampling 630 points from training dataset with (12875, 12875) entries
# Student model 1-7 trained with depth 12 and 47 leaves:
# Student model score: 0.7420201862275032
# Student model 1-7 fidelity: 0.7420201862275032
# ########## Inner-loop Iteration 8/50 ##########
# Sampling 630 points from training dataset with (13064, 13064) entries
# Student model 1-8 trained with depth 10 and 47 leaves:
# Student model score: 0.8220286169906263
# Student model 1-8 fidelity: 0.8220286169906263
# ########## Inner-loop Iteration 9/50 ##########
# Sampling 630 points from training dataset with (13253, 13253) entries
# Student model 1-9 trained with depth 13 and 44 leaves:
# Student model score: 0.7101717455549899
# Student model 1-9 fidelity: 0.7101717455549899
# ########## Inner-loop Iteration 10/50 ##########
# Sampling 630 points from training dataset with (13442, 13442) entries
# Student model 1-10 trained with depth 12 and 44 leaves:
# Student model score: 0.8207637600494743
# Student model 1-10 fidelity: 0.8207637600494743
# ########## Inner-loop Iteration 11/50 ##########
# Sampling 630 points from training dataset with (13631, 13631) entries
# Student model 1-11 trained with depth 12 and 43 leaves:
# Student model score: 0.8219088211510825
# Student model 1-11 fidelity: 0.8219088211510825
# ########## Inner-loop Iteration 12/50 ##########
# Sampling 630 points from training dataset with (13820, 13820) entries
# Student model 1-12 trained with depth 11 and 43 leaves:
# Student model score: 0.7906405709436944
# Student model 1-12 fidelity: 0.7906405709436944
# ########## Inner-loop Iteration 13/50 ##########
# Sampling 630 points from training dataset with (14009, 14009) entries
# Student model 1-13 trained with depth 10 and 41 leaves:
# Student model score: 0.6806757002084106
# Student model 1-13 fidelity: 0.6806757002084106
# ########## Inner-loop Iteration 14/50 ##########
# Sampling 630 points from training dataset with (14198, 14198) entries
# Student model 1-14 trained with depth 10 and 48 leaves:
# Student model score: 0.8674926159211417
# Student model 1-14 fidelity: 0.8674926159211417
# ########## Inner-loop Iteration 15/50 ##########
# Sampling 630 points from training dataset with (14387, 14387) entries
# Student model 1-15 trained with depth 11 and 42 leaves:
# Student model score: 0.8577124201589756
# Student model 1-15 fidelity: 0.8577124201589756
# ########## Inner-loop Iteration 16/50 ##########
# Sampling 630 points from training dataset with (14576, 14576) entries
# Student model 1-16 trained with depth 12 and 45 leaves:
# Student model score: 0.7431145431145432
# Student model 1-16 fidelity: 0.7431145431145432
# ########## Inner-loop Iteration 17/50 ##########
# Sampling 630 points from training dataset with (14765, 14765) entries
# Student model 1-17 trained with depth 11 and 54 leaves:
# Student model score: 0.854159146175953
# Student model 1-17 fidelity: 0.854159146175953
# ########## Inner-loop Iteration 18/50 ##########
# Sampling 630 points from training dataset with (14954, 14954) entries
# Student model 1-18 trained with depth 10 and 40 leaves:
# Student model score: 0.8105016195925288
# Student model 1-18 fidelity: 0.8105016195925288
# ########## Inner-loop Iteration 19/50 ##########
# Sampling 630 points from training dataset with (15143, 15143) entries
# Student model 1-19 trained with depth 12 and 47 leaves:
# Student model score: 0.6570155911147786
# Student model 1-19 fidelity: 0.6570155911147786
# ########## Inner-loop Iteration 20/50 ##########
# Sampling 630 points from training dataset with (15332, 15332) entries
# Student model 1-20 trained with depth 11 and 40 leaves:
# Student model score: 0.8131201086495204
# Student model 1-20 fidelity: 0.8131201086495204
# ########## Inner-loop Iteration 21/50 ##########
# Sampling 630 points from training dataset with (15521, 15521) entries
# Student model 1-21 trained with depth 11 and 45 leaves:
# Student model score: 0.6702191735279971
# Student model 1-21 fidelity: 0.6702191735279971
# ########## Inner-loop Iteration 22/50 ##########
# Sampling 630 points from training dataset with (15710, 15710) entries
# Student model 1-22 trained with depth 12 and 45 leaves:
# Student model score: 0.6218571702809089
# Student model 1-22 fidelity: 0.6218571702809089
# ########## Inner-loop Iteration 23/50 ##########
# Sampling 630 points from training dataset with (15899, 15899) entries
# Student model 1-23 trained with depth 13 and 47 leaves:
# Student model score: 0.7881744016213874
# Student model 1-23 fidelity: 0.7881744016213874
# ########## Inner-loop Iteration 24/50 ##########
# Sampling 630 points from training dataset with (16088, 16088) entries
# Student model 1-24 trained with depth 13 and 43 leaves:
# Student model score: 0.7070563172264378
# Student model 1-24 fidelity: 0.7070563172264378
# ########## Inner-loop Iteration 25/50 ##########
# Sampling 630 points from training dataset with (16277, 16277) entries
# Student model 1-25 trained with depth 10 and 54 leaves:
# Student model score: 0.730067245397958
# Student model 1-25 fidelity: 0.730067245397958
# ########## Inner-loop Iteration 26/50 ##########
# Sampling 630 points from training dataset with (16466, 16466) entries
# Student model 1-26 trained with depth 12 and 47 leaves:
# Student model score: 0.7575778756387815
# Student model 1-26 fidelity: 0.7575778756387815
# ########## Inner-loop Iteration 27/50 ##########
# Sampling 630 points from training dataset with (16655, 16655) entries
# Student model 1-27 trained with depth 11 and 46 leaves:
# Student model score: 0.929709362657591
# Student model 1-27 fidelity: 0.929709362657591
# ########## Inner-loop Iteration 28/50 ##########
# Sampling 630 points from training dataset with (16844, 16844) entries
# Student model 1-28 trained with depth 12 and 42 leaves:
# Student model score: 0.8104461799189107
# Student model 1-28 fidelity: 0.8104461799189107
# ########## Inner-loop Iteration 29/50 ##########
# Sampling 630 points from training dataset with (17033, 17033) entries
# Student model 1-29 trained with depth 11 and 43 leaves:
# Student model score: 0.813445387646155
# Student model 1-29 fidelity: 0.813445387646155
# ########## Inner-loop Iteration 30/50 ##########
# Sampling 630 points from training dataset with (17222, 17222) entries
# Student model 1-30 trained with depth 11 and 44 leaves:
# Student model score: 0.6923033035103875
# Student model 1-30 fidelity: 0.6923033035103875
# ########## Inner-loop Iteration 31/50 ##########
# Sampling 630 points from training dataset with (17411, 17411) entries
# Student model 1-31 trained with depth 13 and 45 leaves:
# Student model score: 0.7738860845256358
# Student model 1-31 fidelity: 0.7738860845256358
# ########## Inner-loop Iteration 32/50 ##########
# Sampling 630 points from training dataset with (17600, 17600) entries
# Student model 1-32 trained with depth 10 and 47 leaves:
# Student model score: 0.698227645962486
# Student model 1-32 fidelity: 0.698227645962486
# ########## Inner-loop Iteration 33/50 ##########
# Sampling 630 points from training dataset with (17789, 17789) entries
# Student model 1-33 trained with depth 10 and 43 leaves:
# Student model score: 0.6984631223060137
# Student model 1-33 fidelity: 0.6984631223060137
# ########## Inner-loop Iteration 34/50 ##########
# Sampling 630 points from training dataset with (17978, 17978) entries
# Student model 1-34 trained with depth 11 and 45 leaves:
# Student model score: 0.7000457875457875
# Student model 1-34 fidelity: 0.7000457875457875
# ########## Inner-loop Iteration 35/50 ##########
# Sampling 630 points from training dataset with (18167, 18167) entries
# Student model 1-35 trained with depth 10 and 38 leaves:
# Student model score: 0.8238087402247803
# Student model 1-35 fidelity: 0.8238087402247803
# ########## Inner-loop Iteration 36/50 ##########
# Sampling 630 points from training dataset with (18356, 18356) entries
# Student model 1-36 trained with depth 12 and 36 leaves:
# Student model score: 0.9123870707752287
# Student model 1-36 fidelity: 0.9123870707752287
# ########## Inner-loop Iteration 37/50 ##########
# Sampling 630 points from training dataset with (18545, 18545) entries
# Student model 1-37 trained with depth 12 and 44 leaves:
# Student model score: 0.8264899045386851
# Student model 1-37 fidelity: 0.8264899045386851
# ########## Inner-loop Iteration 38/50 ##########
# Sampling 630 points from training dataset with (18734, 18734) entries
# Student model 1-38 trained with depth 12 and 46 leaves:
# Student model score: 0.814653104643617
# Student model 1-38 fidelity: 0.814653104643617
# ########## Inner-loop Iteration 39/50 ##########
# Sampling 630 points from training dataset with (18923, 18923) entries
# Student model 1-39 trained with depth 11 and 52 leaves:
# Student model score: 0.9390840770222044
# Student model 1-39 fidelity: 0.9390840770222044
# ########## Inner-loop Iteration 40/50 ##########
# Sampling 630 points from training dataset with (19112, 19112) entries
# Student model 1-40 trained with depth 9 and 44 leaves:
# Student model score: 0.808024211560797
# Student model 1-40 fidelity: 0.808024211560797
# ########## Inner-loop Iteration 41/50 ##########
# Sampling 630 points from training dataset with (19301, 19301) entries
# Student model 1-41 trained with depth 10 and 48 leaves:
# Student model score: 0.8639098667129137
# Student model 1-41 fidelity: 0.8639098667129137
# ########## Inner-loop Iteration 42/50 ##########
# Sampling 630 points from training dataset with (19490, 19490) entries
# Student model 1-42 trained with depth 11 and 41 leaves:
# Student model score: 0.8742653940088878
# Student model 1-42 fidelity: 0.8742653940088878
# ########## Inner-loop Iteration 43/50 ##########
# Sampling 630 points from training dataset with (19679, 19679) entries
# Student model 1-43 trained with depth 12 and 44 leaves:
# Student model score: 0.7715311004784688
# Student model 1-43 fidelity: 0.7715311004784688
# ########## Inner-loop Iteration 44/50 ##########
# Sampling 630 points from training dataset with (19868, 19868) entries
# Student model 1-44 trained with depth 10 and 45 leaves:
# Student model score: 0.8415850271732624
# Student model 1-44 fidelity: 0.8415850271732624
# ########## Inner-loop Iteration 45/50 ##########
# Sampling 630 points from training dataset with (20057, 20057) entries
# Student model 1-45 trained with depth 14 and 46 leaves:
# Student model score: 0.7237648236476129
# Student model 1-45 fidelity: 0.7237648236476129
# ########## Inner-loop Iteration 46/50 ##########
# Sampling 630 points from training dataset with (20246, 20246) entries
# Student model 1-46 trained with depth 9 and 34 leaves:
# Student model score: 0.7563955831436352
# Student model 1-46 fidelity: 0.7563955831436352
# ########## Inner-loop Iteration 47/50 ##########
# Sampling 630 points from training dataset with (20435, 20435) entries
# Student model 1-47 trained with depth 11 and 40 leaves:
# Student model score: 0.8242329628043913
# Student model 1-47 fidelity: 0.8242329628043913
# ########## Inner-loop Iteration 48/50 ##########
# Sampling 630 points from training dataset with (20624, 20624) entries
# Student model 1-48 trained with depth 11 and 41 leaves:
# Student model score: 0.8668739399213621
# Student model 1-48 fidelity: 0.8668739399213621
# ########## Inner-loop Iteration 49/50 ##########
# Sampling 630 points from training dataset with (20813, 20813) entries
# Student model 1-49 trained with depth 13 and 50 leaves:
# Student model score: 0.7316447604682899
# Student model 1-49 fidelity: 0.7316447604682899
# ########## Outer-loop Iteration 2/10 ##########
# Initializing Trustee inner-loop with 10 iterations
# ########## Inner-loop Iteration 0/50 ##########
# Sampling 630 points from training dataset with (21002, 21002) entries
# Student model 2-0 trained with depth 11 and 48 leaves:
# Student model score: 0.8693834186492162
# Student model 2-0 fidelity: 0.8693834186492162
# ########## Inner-loop Iteration 1/50 ##########
# Sampling 630 points from training dataset with (21191, 21191) entries
# Student model 2-1 trained with depth 13 and 41 leaves:
# Student model score: 0.7687800723779278
# Student model 2-1 fidelity: 0.7687800723779278
# ########## Inner-loop Iteration 2/50 ##########
# Sampling 630 points from training dataset with (21380, 21380) entries
# Student model 2-2 trained with depth 11 and 38 leaves:
# Student model score: 0.7457473631892236
# Student model 2-2 fidelity: 0.7457473631892236
# ########## Inner-loop Iteration 3/50 ##########
# Sampling 630 points from training dataset with (21569, 21569) entries
# Student model 2-3 trained with depth 10 and 46 leaves:
# Student model score: 0.7278510278328972
# Student model 2-3 fidelity: 0.7278510278328972
# ########## Inner-loop Iteration 4/50 ##########
# Sampling 630 points from training dataset with (21758, 21758) entries
# Student model 2-4 trained with depth 11 and 42 leaves:
# Student model score: 0.646567935823806
# Student model 2-4 fidelity: 0.646567935823806
# ########## Inner-loop Iteration 5/50 ##########
# Sampling 630 points from training dataset with (21947, 21947) entries
# Student model 2-5 trained with depth 13 and 44 leaves:
# Student model score: 0.8894124024379986
# Student model 2-5 fidelity: 0.8894124024379986
# ########## Inner-loop Iteration 6/50 ##########
# Sampling 630 points from training dataset with (22136, 22136) entries
# Student model 2-6 trained with depth 11 and 47 leaves:
# Student model score: 0.754781796528717
# Student model 2-6 fidelity: 0.754781796528717
# ########## Inner-loop Iteration 7/50 ##########
# Sampling 630 points from training dataset with (22325, 22325) entries
# Student model 2-7 trained with depth 11 and 44 leaves:
# Student model score: 0.6803035128172814
# Student model 2-7 fidelity: 0.6803035128172814
# ########## Inner-loop Iteration 8/50 ##########
# Sampling 630 points from training dataset with (22514, 22514) entries
# Student model 2-8 trained with depth 11 and 44 leaves:
# Student model score: 0.7681803864303864
# Student model 2-8 fidelity: 0.7681803864303864
# ########## Inner-loop Iteration 9/50 ##########
# Sampling 630 points from training dataset with (22703, 22703) entries
# Student model 2-9 trained with depth 11 and 38 leaves:
# Student model score: 0.63329004123131
# Student model 2-9 fidelity: 0.63329004123131
# ########## Inner-loop Iteration 10/50 ##########
# Sampling 630 points from training dataset with (22892, 22892) entries
# Student model 2-10 trained with depth 12 and 46 leaves:
# Student model score: 0.7804711742550019
# Student model 2-10 fidelity: 0.7804711742550019
# ########## Inner-loop Iteration 11/50 ##########
# Sampling 630 points from training dataset with (23081, 23081) entries
# Student model 2-11 trained with depth 12 and 50 leaves:
# Student model score: 0.7508996438084853
# Student model 2-11 fidelity: 0.7508996438084853
# ########## Inner-loop Iteration 12/50 ##########
# Sampling 630 points from training dataset with (23270, 23270) entries
# Student model 2-12 trained with depth 12 and 44 leaves:
# Student model score: 0.5622455400683913
# Student model 2-12 fidelity: 0.5622455400683913
# ########## Inner-loop Iteration 13/50 ##########
# Sampling 630 points from training dataset with (23459, 23459) entries
# Student model 2-13 trained with depth 12 and 46 leaves:
# Student model score: 0.8169355841153532
# Student model 2-13 fidelity: 0.8169355841153532
# ########## Inner-loop Iteration 14/50 ##########
# Sampling 630 points from training dataset with (23648, 23648) entries
# Student model 2-14 trained with depth 11 and 47 leaves:
# Student model score: 0.7536355410348506
# Student model 2-14 fidelity: 0.7536355410348506
# ########## Inner-loop Iteration 15/50 ##########
# Sampling 630 points from training dataset with (23837, 23837) entries
# Student model 2-15 trained with depth 11 and 41 leaves:
# Student model score: 0.7195389382436284
# Student model 2-15 fidelity: 0.7195389382436284
# ########## Inner-loop Iteration 16/50 ##########
# Sampling 630 points from training dataset with (24026, 24026) entries
# Student model 2-16 trained with depth 10 and 49 leaves:
# Student model score: 0.8215690767166752
# Student model 2-16 fidelity: 0.8215690767166752
# ########## Inner-loop Iteration 17/50 ##########
# Sampling 630 points from training dataset with (24215, 24215) entries
# Student model 2-17 trained with depth 14 and 48 leaves:
# Student model score: 0.8093101651458697
# Student model 2-17 fidelity: 0.8093101651458697
# ########## Inner-loop Iteration 18/50 ##########
# Sampling 630 points from training dataset with (24404, 24404) entries
# Student model 2-18 trained with depth 14 and 50 leaves:
# Student model score: 0.7142887978940542
# Student model 2-18 fidelity: 0.7142887978940542
# ########## Inner-loop Iteration 19/50 ##########
# Sampling 630 points from training dataset with (24593, 24593) entries
# Student model 2-19 trained with depth 12 and 44 leaves:
# Student model score: 0.8098097146321317
# Student model 2-19 fidelity: 0.8098097146321317
# ########## Inner-loop Iteration 20/50 ##########
# Sampling 630 points from training dataset with (24782, 24782) entries
# Student model 2-20 trained with depth 12 and 51 leaves:
# Student model score: 0.7371075650740965
# Student model 2-20 fidelity: 0.7371075650740965
# ########## Inner-loop Iteration 21/50 ##########
# Sampling 630 points from training dataset with (24971, 24971) entries
# Student model 2-21 trained with depth 12 and 49 leaves:
# Student model score: 0.8569198299140257
# Student model 2-21 fidelity: 0.8569198299140257
# ########## Inner-loop Iteration 22/50 ##########
# Sampling 630 points from training dataset with (25160, 25160) entries
# Student model 2-22 trained with depth 12 and 38 leaves:
# Student model score: 0.7235838333588721
# Student model 2-22 fidelity: 0.7235838333588721
# ########## Inner-loop Iteration 23/50 ##########
# Sampling 630 points from training dataset with (25349, 25349) entries
# Student model 2-23 trained with depth 11 and 42 leaves:
# Student model score: 0.736764237370923
# Student model 2-23 fidelity: 0.736764237370923
# ########## Inner-loop Iteration 24/50 ##########
# Sampling 630 points from training dataset with (25538, 25538) entries
# Student model 2-24 trained with depth 11 and 43 leaves:
# Student model score: 0.6766134658991803
# Student model 2-24 fidelity: 0.6766134658991803
# ########## Inner-loop Iteration 25/50 ##########
# Sampling 630 points from training dataset with (25727, 25727) entries
# Student model 2-25 trained with depth 12 and 50 leaves:
# Student model score: 0.8046546369114725
# Student model 2-25 fidelity: 0.8046546369114725
# ########## Inner-loop Iteration 26/50 ##########
# Sampling 630 points from training dataset with (25916, 25916) entries
# Student model 2-26 trained with depth 12 and 41 leaves:
# Student model score: 0.8049942394769981
# Student model 2-26 fidelity: 0.8049942394769981
# ########## Inner-loop Iteration 27/50 ##########
# Sampling 630 points from training dataset with (26105, 26105) entries
# Student model 2-27 trained with depth 10 and 52 leaves:
# Student model score: 0.8400434532787473
# Student model 2-27 fidelity: 0.8400434532787473
# ########## Inner-loop Iteration 28/50 ##########
# Sampling 630 points from training dataset with (26294, 26294) entries
# Student model 2-28 trained with depth 10 and 41 leaves:
# Student model score: 0.9345210302876207
# Student model 2-28 fidelity: 0.9345210302876207
# ########## Inner-loop Iteration 29/50 ##########
# Sampling 630 points from training dataset with (26483, 26483) entries
# Student model 2-29 trained with depth 11 and 43 leaves:
# Student model score: 0.8633704126970381
# Student model 2-29 fidelity: 0.8633704126970381
# ########## Inner-loop Iteration 30/50 ##########
# Sampling 630 points from training dataset with (26672, 26672) entries
# Student model 2-30 trained with depth 12 and 51 leaves:
# Student model score: 0.8548864256311064
# Student model 2-30 fidelity: 0.8548864256311064
# ########## Inner-loop Iteration 31/50 ##########
# Sampling 630 points from training dataset with (26861, 26861) entries
# Student model 2-31 trained with depth 11 and 46 leaves:
# Student model score: 0.7490112922071831
# Student model 2-31 fidelity: 0.7490112922071831
# ########## Inner-loop Iteration 32/50 ##########
# Sampling 630 points from training dataset with (27050, 27050) entries
# Student model 2-32 trained with depth 11 and 48 leaves:
# Student model score: 0.6439472763397495
# Student model 2-32 fidelity: 0.6439472763397495
# ########## Inner-loop Iteration 33/50 ##########
# Sampling 630 points from training dataset with (27239, 27239) entries
# Student model 2-33 trained with depth 11 and 49 leaves:
# Student model score: 0.7449187185046581
# Student model 2-33 fidelity: 0.7449187185046581
# ########## Inner-loop Iteration 34/50 ##########
# Sampling 630 points from training dataset with (27428, 27428) entries
# Student model 2-34 trained with depth 10 and 44 leaves:
# Student model score: 0.8631958379784468
# Student model 2-34 fidelity: 0.8631958379784468
# ########## Inner-loop Iteration 35/50 ##########
# Sampling 630 points from training dataset with (27617, 27617) entries
# Student model 2-35 trained with depth 11 and 51 leaves:
# Student model score: 0.7048006606596985
# Student model 2-35 fidelity: 0.7048006606596985
# ########## Inner-loop Iteration 36/50 ##########
# Sampling 630 points from training dataset with (27806, 27806) entries
# Student model 2-36 trained with depth 10 and 43 leaves:
# Student model score: 0.6493155076898496
# Student model 2-36 fidelity: 0.6493155076898496
# ########## Inner-loop Iteration 37/50 ##########
# Sampling 630 points from training dataset with (27995, 27995) entries
# Student model 2-37 trained with depth 11 and 49 leaves:
# Student model score: 0.869702376125213
# Student model 2-37 fidelity: 0.869702376125213
# ########## Inner-loop Iteration 38/50 ##########
# Sampling 630 points from training dataset with (28184, 28184) entries
# Student model 2-38 trained with depth 13 and 43 leaves:
# Student model score: 0.686047856475884
# Student model 2-38 fidelity: 0.686047856475884
# ########## Inner-loop Iteration 39/50 ##########
# Sampling 630 points from training dataset with (28373, 28373) entries
# Student model 2-39 trained with depth 12 and 43 leaves:
# Student model score: 0.8820479797979799
# Student model 2-39 fidelity: 0.8820479797979799
# ########## Inner-loop Iteration 40/50 ##########
# Sampling 630 points from training dataset with (28562, 28562) entries
# Student model 2-40 trained with depth 10 and 41 leaves:
# Student model score: 0.7693234290961563
# Student model 2-40 fidelity: 0.7693234290961563
# ########## Inner-loop Iteration 41/50 ##########
# Sampling 630 points from training dataset with (28751, 28751) entries
# Student model 2-41 trained with depth 12 and 46 leaves:
# Student model score: 0.8251204386000626
# Student model 2-41 fidelity: 0.8251204386000626
# ########## Inner-loop Iteration 42/50 ##########
# Sampling 630 points from training dataset with (28940, 28940) entries
# Student model 2-42 trained with depth 12 and 47 leaves:
# Student model score: 0.8024421956946384
# Student model 2-42 fidelity: 0.8024421956946384
# ########## Inner-loop Iteration 43/50 ##########
# Sampling 630 points from training dataset with (29129, 29129) entries
# Student model 2-43 trained with depth 11 and 41 leaves:
# Student model score: 0.6470509101985948
# Student model 2-43 fidelity: 0.6470509101985948
# ########## Inner-loop Iteration 44/50 ##########
# Sampling 630 points from training dataset with (29318, 29318) entries
# Student model 2-44 trained with depth 10 and 45 leaves:
# Student model score: 0.7293275134451606
# Student model 2-44 fidelity: 0.7293275134451606
# ########## Inner-loop Iteration 45/50 ##########
# Sampling 630 points from training dataset with (29507, 29507) entries
# Student model 2-45 trained with depth 10 and 42 leaves:
# Student model score: 0.7515438437637106
# Student model 2-45 fidelity: 0.7515438437637106
# ########## Inner-loop Iteration 46/50 ##########
# Sampling 630 points from training dataset with (29696, 29696) entries
# Student model 2-46 trained with depth 12 and 44 leaves:
# Student model score: 0.7524784106651223
# Student model 2-46 fidelity: 0.7524784106651223
# ########## Inner-loop Iteration 47/50 ##########
# Sampling 630 points from training dataset with (29885, 29885) entries
# Student model 2-47 trained with depth 10 and 38 leaves:
# Student model score: 0.6170802286614027
# Student model 2-47 fidelity: 0.6170802286614027
# ########## Inner-loop Iteration 48/50 ##########
# Sampling 630 points from training dataset with (30074, 30074) entries
# Student model 2-48 trained with depth 10 and 36 leaves:
# Student model score: 0.7098300726082903
# Student model 2-48 fidelity: 0.7098300726082903
# ########## Inner-loop Iteration 49/50 ##########
# Sampling 630 points from training dataset with (30263, 30263) entries
# Student model 2-49 trained with depth 14 and 44 leaves:
# Student model score: 0.7671857258494087
# Student model 2-49 fidelity: 0.7671857258494087
# ########## Outer-loop Iteration 3/10 ##########
# Initializing Trustee inner-loop with 10 iterations
# ########## Inner-loop Iteration 0/50 ##########
# Sampling 630 points from training dataset with (30452, 30452) entries
# Student model 3-0 trained with depth 11 and 43 leaves:
# Student model score: 0.8644563279857398
# Student model 3-0 fidelity: 0.8644563279857398
# ########## Inner-loop Iteration 1/50 ##########
# Sampling 630 points from training dataset with (30641, 30641) entries
# Student model 3-1 trained with depth 10 and 38 leaves:
# Student model score: 0.7219871789291853
# Student model 3-1 fidelity: 0.7219871789291853
# ########## Inner-loop Iteration 2/50 ##########
# Sampling 630 points from training dataset with (30830, 30830) entries
# Student model 3-2 trained with depth 11 and 47 leaves:
# Student model score: 0.9105162752791649
# Student model 3-2 fidelity: 0.9105162752791649
# ########## Inner-loop Iteration 3/50 ##########
# Sampling 630 points from training dataset with (31019, 31019) entries
# Student model 3-3 trained with depth 11 and 47 leaves:
# Student model score: 0.6963118268739431
# Student model 3-3 fidelity: 0.6963118268739431
# ########## Inner-loop Iteration 4/50 ##########
# Sampling 630 points from training dataset with (31208, 31208) entries
# Student model 3-4 trained with depth 11 and 43 leaves:
# Student model score: 0.7042012526787985
# Student model 3-4 fidelity: 0.7042012526787985
# ########## Inner-loop Iteration 5/50 ##########
# Sampling 630 points from training dataset with (31397, 31397) entries
# Student model 3-5 trained with depth 12 and 44 leaves:
# Student model score: 0.8581244766009091
# Student model 3-5 fidelity: 0.8581244766009091
# ########## Inner-loop Iteration 6/50 ##########
# Sampling 630 points from training dataset with (31586, 31586) entries
# Student model 3-6 trained with depth 12 and 45 leaves:
# Student model score: 0.7124478074970578
# Student model 3-6 fidelity: 0.7124478074970578
# ########## Inner-loop Iteration 7/50 ##########
# Sampling 630 points from training dataset with (31775, 31775) entries
# Student model 3-7 trained with depth 9 and 39 leaves:
# Student model score: 0.7145976130351132
# Student model 3-7 fidelity: 0.7145976130351132
# ########## Inner-loop Iteration 8/50 ##########
# Sampling 630 points from training dataset with (31964, 31964) entries
# Student model 3-8 trained with depth 11 and 45 leaves:
# Student model score: 0.8345387473047049
# Student model 3-8 fidelity: 0.8345387473047049
# ########## Inner-loop Iteration 9/50 ##########
# Sampling 630 points from training dataset with (32153, 32153) entries
# Student model 3-9 trained with depth 12 and 45 leaves:
# Student model score: 0.7982473544973545
# Student model 3-9 fidelity: 0.7982473544973545
# ########## Inner-loop Iteration 10/50 ##########
# Sampling 630 points from training dataset with (32342, 32342) entries
# Student model 3-10 trained with depth 11 and 47 leaves:
# Student model score: 0.6346189413291018
# Student model 3-10 fidelity: 0.6346189413291018
# ########## Inner-loop Iteration 11/50 ##########
# Sampling 630 points from training dataset with (32531, 32531) entries
# Student model 3-11 trained with depth 11 and 39 leaves:
# Student model score: 0.8002438024834442
# Student model 3-11 fidelity: 0.8002438024834442
# ########## Inner-loop Iteration 12/50 ##########
# Sampling 630 points from training dataset with (32720, 32720) entries
# Student model 3-12 trained with depth 10 and 49 leaves:
# Student model score: 0.7236094979997418
# Student model 3-12 fidelity: 0.7236094979997418
# ########## Inner-loop Iteration 13/50 ##########
# Sampling 630 points from training dataset with (32909, 32909) entries
# Student model 3-13 trained with depth 13 and 43 leaves:
# Student model score: 0.820414545764265
# Student model 3-13 fidelity: 0.820414545764265
# ########## Inner-loop Iteration 14/50 ##########
# Sampling 630 points from training dataset with (33098, 33098) entries
# Student model 3-14 trained with depth 13 and 47 leaves:
# Student model score: 0.7631403577962274
# Student model 3-14 fidelity: 0.7631403577962274
# ########## Inner-loop Iteration 15/50 ##########
# Sampling 630 points from training dataset with (33287, 33287) entries
# Student model 3-15 trained with depth 11 and 46 leaves:
# Student model score: 0.8150174751139071
# Student model 3-15 fidelity: 0.8150174751139071
# ########## Inner-loop Iteration 16/50 ##########
# Sampling 630 points from training dataset with (33476, 33476) entries
# Student model 3-16 trained with depth 10 and 50 leaves:
# Student model score: 0.7278290514645741
# Student model 3-16 fidelity: 0.7278290514645741
# ########## Inner-loop Iteration 17/50 ##########
# Sampling 630 points from training dataset with (33665, 33665) entries
# Student model 3-17 trained with depth 12 and 48 leaves:
# Student model score: 0.6876938856350621
# Student model 3-17 fidelity: 0.6876938856350621
# ########## Inner-loop Iteration 18/50 ##########
# Sampling 630 points from training dataset with (33854, 33854) entries
# Student model 3-18 trained with depth 12 and 42 leaves:
# Student model score: 0.7808584010158778
# Student model 3-18 fidelity: 0.7808584010158778
# ########## Inner-loop Iteration 19/50 ##########
# Sampling 630 points from training dataset with (34043, 34043) entries
# Student model 3-19 trained with depth 13 and 46 leaves:
# Student model score: 0.6983816393716283
# Student model 3-19 fidelity: 0.6983816393716283
# ########## Inner-loop Iteration 20/50 ##########
# Sampling 630 points from training dataset with (34232, 34232) entries
# Student model 3-20 trained with depth 13 and 49 leaves:
# Student model score: 0.896529493720163
# Student model 3-20 fidelity: 0.896529493720163
# ########## Inner-loop Iteration 21/50 ##########
# Sampling 630 points from training dataset with (34421, 34421) entries
# Student model 3-21 trained with depth 10 and 37 leaves:
# Student model score: 0.7586452762923351
# Student model 3-21 fidelity: 0.7586452762923351
# ########## Inner-loop Iteration 22/50 ##########
# Sampling 630 points from training dataset with (34610, 34610) entries
# Student model 3-22 trained with depth 11 and 38 leaves:
# Student model score: 0.7028692031584992
# Student model 3-22 fidelity: 0.7028692031584992
# ########## Inner-loop Iteration 23/50 ##########
# Sampling 630 points from training dataset with (34799, 34799) entries
# Student model 3-23 trained with depth 11 and 41 leaves:
# Student model score: 0.7109419319737883
# Student model 3-23 fidelity: 0.7109419319737883
# ########## Inner-loop Iteration 24/50 ##########
# Sampling 630 points from training dataset with (34988, 34988) entries
# Student model 3-24 trained with depth 10 and 48 leaves:
# Student model score: 0.7917647567193846
# Student model 3-24 fidelity: 0.7917647567193846
# ########## Inner-loop Iteration 25/50 ##########
# Sampling 630 points from training dataset with (35177, 35177) entries
# Student model 3-25 trained with depth 13 and 46 leaves:
# Student model score: 0.676474465223425
# Student model 3-25 fidelity: 0.676474465223425
# ########## Inner-loop Iteration 26/50 ##########
# Sampling 630 points from training dataset with (35366, 35366) entries
# Student model 3-26 trained with depth 12 and 42 leaves:
# Student model score: 0.8965710215710215
# Student model 3-26 fidelity: 0.8965710215710215
# ########## Inner-loop Iteration 27/50 ##########
# Sampling 630 points from training dataset with (35555, 35555) entries
# Student model 3-27 trained with depth 14 and 53 leaves:
# Student model score: 0.8137379533104151
# Student model 3-27 fidelity: 0.8137379533104151
# ########## Inner-loop Iteration 28/50 ##########
# Sampling 630 points from training dataset with (35744, 35744) entries
# Student model 3-28 trained with depth 13 and 46 leaves:
# Student model score: 0.7590392332888211
# Student model 3-28 fidelity: 0.7590392332888211
# ########## Inner-loop Iteration 29/50 ##########
# Sampling 630 points from training dataset with (35933, 35933) entries
# Student model 3-29 trained with depth 9 and 44 leaves:
# Student model score: 0.7668627098380506
# Student model 3-29 fidelity: 0.7668627098380506
# ########## Inner-loop Iteration 30/50 ##########
# Sampling 630 points from training dataset with (36122, 36122) entries
# Student model 3-30 trained with depth 9 and 44 leaves:
# Student model score: 0.782825000030913
# Student model 3-30 fidelity: 0.782825000030913
# ########## Inner-loop Iteration 31/50 ##########
# ...
# Student model 8-39 trained with depth 16 and 53 leaves:
# Student model score: 0.7103943309592182
# Student model 8-39 fidelity: 0.7103943309592182
# ########## Inner-loop Iteration 40/50 ##########
# Sampling 630 points from training dataset with (85262, 85262) entries
# Student model 8-40 trained with depth 10 and 42 leaves:
# Student model score: 0.755768272905722
# Student model 8-40 fidelity: 0.755768272905722
# ########## Inner-loop Iteration 41/50 ##########
# Sampling 630 points from training dataset with (85451, 85451) entries
# Student model 8-41 trained with depth 9 and 44 leaves:
# Student model score: 0.8163259623463771
# Student model 8-41 fidelity: 0.8163259623463771
# ########## Inner-loop Iteration 42/50 ##########
# Sampling 630 points from training dataset with (85640, 85640) entries
# Student model 8-42 trained with depth 12 and 40 leaves:
# Student model score: 0.7381356724999302
# Student model 8-42 fidelity: 0.7381356724999302
# ########## Inner-loop Iteration 43/50 ##########
# Sampling 630 points from training dataset with (85829, 85829) entries
# Student model 8-43 trained with depth 10 and 40 leaves:
# Student model score: 0.876883830455259
# Student model 8-43 fidelity: 0.876883830455259
# ########## Inner-loop Iteration 44/50 ##########
# Sampling 630 points from training dataset with (86018, 86018) entries
# Student model 8-44 trained with depth 10 and 44 leaves:
# Student model score: 0.7601593339820717
# Student model 8-44 fidelity: 0.7601593339820717
# ########## Inner-loop Iteration 45/50 ##########
# Sampling 630 points from training dataset with (86207, 86207) entries
# Student model 8-45 trained with depth 10 and 43 leaves:
# Student model score: 0.7660456118530652
# Student model 8-45 fidelity: 0.7660456118530652
# ########## Inner-loop Iteration 46/50 ##########
# Sampling 630 points from training dataset with (86396, 86396) entries
# Student model 8-46 trained with depth 12 and 48 leaves:
# Student model score: 0.7492308474155421
# Student model 8-46 fidelity: 0.7492308474155421
# ########## Inner-loop Iteration 47/50 ##########
# Sampling 630 points from training dataset with (86585, 86585) entries
# Student model 8-47 trained with depth 14 and 52 leaves:
# Student model score: 0.8021694094304387
# Student model 8-47 fidelity: 0.8021694094304387
# ########## Inner-loop Iteration 48/50 ##########
# Sampling 630 points from training dataset with (86774, 86774) entries
# Student model 8-48 trained with depth 12 and 45 leaves:
# Student model score: 0.7675860581640809
# Student model 8-48 fidelity: 0.7675860581640809
# ########## Inner-loop Iteration 49/50 ##########
# Sampling 630 points from training dataset with (86963, 86963) entries
# Student model 8-49 trained with depth 12 and 41 leaves:
# Student model score: 0.7045530740445995
# Student model 8-49 fidelity: 0.7045530740445995
# ########## Outer-loop Iteration 9/10 ##########
# Initializing Trustee inner-loop with 10 iterations
# ########## Inner-loop Iteration 0/50 ##########
# Sampling 630 points from training dataset with (87152, 87152) entries
# Student model 9-0 trained with depth 9 and 37 leaves:
# Student model score: 0.7143077122239219
# Student model 9-0 fidelity: 0.7143077122239219
# ########## Inner-loop Iteration 1/50 ##########
# Sampling 630 points from training dataset with (87341, 87341) entries
# Student model 9-1 trained with depth 11 and 41 leaves:
# Student model score: 0.8016410604645898
# Student model 9-1 fidelity: 0.8016410604645898
# ########## Inner-loop Iteration 2/50 ##########
# Sampling 630 points from training dataset with (87530, 87530) entries
# Student model 9-2 trained with depth 11 and 47 leaves:
# Student model score: 0.793846688677967
# Student model 9-2 fidelity: 0.793846688677967
# ########## Inner-loop Iteration 3/50 ##########
# Sampling 630 points from training dataset with (87719, 87719) entries
# Student model 9-3 trained with depth 10 and 47 leaves:
# Student model score: 0.7547099747589189
# Student model 9-3 fidelity: 0.7547099747589189
# ########## Inner-loop Iteration 4/50 ##########
# Sampling 630 points from training dataset with (87908, 87908) entries
# Student model 9-4 trained with depth 9 and 36 leaves:
# Student model score: 0.6956876088518206
# Student model 9-4 fidelity: 0.6956876088518206
# ########## Inner-loop Iteration 5/50 ##########
# Sampling 630 points from training dataset with (88097, 88097) entries
# Student model 9-5 trained with depth 9 and 39 leaves:
# Student model score: 0.7407860239132561
# Student model 9-5 fidelity: 0.7407860239132561
# ########## Inner-loop Iteration 6/50 ##########
# Sampling 630 points from training dataset with (88286, 88286) entries
# Student model 9-6 trained with depth 11 and 43 leaves:
# Student model score: 0.8339531493450413
# Student model 9-6 fidelity: 0.8339531493450413
# ########## Inner-loop Iteration 7/50 ##########
# Sampling 630 points from training dataset with (88475, 88475) entries
# Student model 9-7 trained with depth 11 and 39 leaves:
# Student model score: 0.7179929780258726
# Student model 9-7 fidelity: 0.7179929780258726
# ########## Inner-loop Iteration 8/50 ##########
# Sampling 630 points from training dataset with (88664, 88664) entries
# Student model 9-8 trained with depth 12 and 47 leaves:
# Student model score: 0.8530730067608948
# Student model 9-8 fidelity: 0.8530730067608948
# ########## Inner-loop Iteration 9/50 ##########
# Sampling 630 points from training dataset with (88853, 88853) entries
# Student model 9-9 trained with depth 10 and 46 leaves:
# Student model score: 0.8983802711240828
# Student model 9-9 fidelity: 0.8983802711240828
# ########## Inner-loop Iteration 10/50 ##########
# Sampling 630 points from training dataset with (89042, 89042) entries
# Student model 9-10 trained with depth 12 and 50 leaves:
# Student model score: 0.8112894502529904
# Student model 9-10 fidelity: 0.8112894502529904
# ########## Inner-loop Iteration 11/50 ##########
# Sampling 630 points from training dataset with (89231, 89231) entries
# Student model 9-11 trained with depth 11 and 48 leaves:
# Student model score: 0.6946728237886775
# Student model 9-11 fidelity: 0.6946728237886775
# ########## Inner-loop Iteration 12/50 ##########
# Sampling 630 points from training dataset with (89420, 89420) entries
# Student model 9-12 trained with depth 11 and 38 leaves:
# Student model score: 0.8016989178896989
# Student model 9-12 fidelity: 0.8016989178896989
# ########## Inner-loop Iteration 13/50 ##########
# Sampling 630 points from training dataset with (89609, 89609) entries
# Student model 9-13 trained with depth 10 and 43 leaves:
# Student model score: 0.8132403989304233
# Student model 9-13 fidelity: 0.8132403989304233
# ########## Inner-loop Iteration 14/50 ##########
# Sampling 630 points from training dataset with (89798, 89798) entries
# Student model 9-14 trained with depth 10 and 45 leaves:
# Student model score: 0.6368572362409034
# Student model 9-14 fidelity: 0.6368572362409034
# ########## Inner-loop Iteration 15/50 ##########
# Sampling 630 points from training dataset with (89987, 89987) entries
# Student model 9-15 trained with depth 10 and 49 leaves:
# Student model score: 0.6987798082125457
# Student model 9-15 fidelity: 0.6987798082125457
# ########## Inner-loop Iteration 16/50 ##########
# Sampling 630 points from training dataset with (90176, 90176) entries
# Student model 9-16 trained with depth 8 and 40 leaves:
# Student model score: 0.8676885053480798
# Student model 9-16 fidelity: 0.8676885053480798
# ########## Inner-loop Iteration 17/50 ##########
# Sampling 630 points from training dataset with (90365, 90365) entries
# Student model 9-17 trained with depth 12 and 46 leaves:
# Student model score: 0.9163467251702546
# Student model 9-17 fidelity: 0.9163467251702546
# ########## Inner-loop Iteration 18/50 ##########
# Sampling 630 points from training dataset with (90554, 90554) entries
# Student model 9-18 trained with depth 10 and 45 leaves:
# Student model score: 0.8885547336174128
# Student model 9-18 fidelity: 0.8885547336174128
# ########## Inner-loop Iteration 19/50 ##########
# Sampling 630 points from training dataset with (90743, 90743) entries
# Student model 9-19 trained with depth 9 and 45 leaves:
# Student model score: 0.7706537085262442
# Student model 9-19 fidelity: 0.7706537085262442
# ########## Inner-loop Iteration 20/50 ##########
# Sampling 630 points from training dataset with (90932, 90932) entries
# Student model 9-20 trained with depth 13 and 48 leaves:
# Student model score: 0.8295442178495874
# Student model 9-20 fidelity: 0.8295442178495874
# ########## Inner-loop Iteration 21/50 ##########
# Sampling 630 points from training dataset with (91121, 91121) entries
# Student model 9-21 trained with depth 12 and 45 leaves:
# Student model score: 0.7106481977321578
# Student model 9-21 fidelity: 0.7106481977321578
# ########## Inner-loop Iteration 22/50 ##########
# Sampling 630 points from training dataset with (91310, 91310) entries
# Student model 9-22 trained with depth 11 and 47 leaves:
# Student model score: 0.7537182027012536
# Student model 9-22 fidelity: 0.7537182027012536
# ########## Inner-loop Iteration 23/50 ##########
# Sampling 630 points from training dataset with (91499, 91499) entries
# Student model 9-23 trained with depth 11 and 44 leaves:
# Student model score: 0.8655443322109988
# Student model 9-23 fidelity: 0.8655443322109988
# ########## Inner-loop Iteration 24/50 ##########
# Sampling 630 points from training dataset with (91688, 91688) entries
# Student model 9-24 trained with depth 11 and 39 leaves:
# Student model score: 0.7228550679531072
# Student model 9-24 fidelity: 0.7228550679531072
# ########## Inner-loop Iteration 25/50 ##########
# Sampling 630 points from training dataset with (91877, 91877) entries
# Student model 9-25 trained with depth 11 and 44 leaves:
# Student model score: 0.7675885222306885
# Student model 9-25 fidelity: 0.7675885222306885
# ########## Inner-loop Iteration 26/50 ##########
# Sampling 630 points from training dataset with (92066, 92066) entries
# Student model 9-26 trained with depth 13 and 41 leaves:
# Student model score: 0.7140447515447516
# Student model 9-26 fidelity: 0.7140447515447516
# ########## Inner-loop Iteration 27/50 ##########
# Sampling 630 points from training dataset with (92255, 92255) entries
# Student model 9-27 trained with depth 11 and 46 leaves:
# Student model score: 0.7353696741854635
# Student model 9-27 fidelity: 0.7353696741854635
# ########## Inner-loop Iteration 28/50 ##########
# Sampling 630 points from training dataset with (92444, 92444) entries
# Student model 9-28 trained with depth 9 and 40 leaves:
# Student model score: 0.8296769896769897
# Student model 9-28 fidelity: 0.8296769896769897
# ########## Inner-loop Iteration 29/50 ##########
# Sampling 630 points from training dataset with (92633, 92633) entries
# Student model 9-29 trained with depth 11 and 46 leaves:
# Student model score: 0.7759857936781227
# Student model 9-29 fidelity: 0.7759857936781227
# ########## Inner-loop Iteration 30/50 ##########
# Sampling 630 points from training dataset with (92822, 92822) entries
# Student model 9-30 trained with depth 10 and 41 leaves:
# Student model score: 0.8636808503470116
# Student model 9-30 fidelity: 0.8636808503470116
# ########## Inner-loop Iteration 31/50 ##########
# Sampling 630 points from training dataset with (93011, 93011) entries
# Student model 9-31 trained with depth 11 and 44 leaves:
# Student model score: 0.8979416146177996
# Student model 9-31 fidelity: 0.8979416146177996
# ########## Inner-loop Iteration 32/50 ##########
# Sampling 630 points from training dataset with (93200, 93200) entries
# Student model 9-32 trained with depth 10 and 40 leaves:
# Student model score: 0.7960423018876717
# Student model 9-32 fidelity: 0.7960423018876717
# ########## Inner-loop Iteration 33/50 ##########
# Sampling 630 points from training dataset with (93389, 93389) entries
# Student model 9-33 trained with depth 9 and 44 leaves:
# Student model score: 0.8121617182737726
# Student model 9-33 fidelity: 0.8121617182737726
# ########## Inner-loop Iteration 34/50 ##########
# Sampling 630 points from training dataset with (93578, 93578) entries
# Student model 9-34 trained with depth 14 and 51 leaves:
# Student model score: 0.7526968194291154
# Student model 9-34 fidelity: 0.7526968194291154
# ########## Inner-loop Iteration 35/50 ##########
# Sampling 630 points from training dataset with (93767, 93767) entries
# Student model 9-35 trained with depth 12 and 45 leaves:
# Student model score: 0.6586076934761146
# Student model 9-35 fidelity: 0.6586076934761146
# ########## Inner-loop Iteration 36/50 ##########
# Sampling 630 points from training dataset with (93956, 93956) entries
# Student model 9-36 trained with depth 11 and 42 leaves:
# Student model score: 0.7387111651792497
# Student model 9-36 fidelity: 0.7387111651792497
# ########## Inner-loop Iteration 37/50 ##########
# Sampling 630 points from training dataset with (94145, 94145) entries
# Student model 9-37 trained with depth 13 and 42 leaves:
# Student model score: 0.8452007180703056
# Student model 9-37 fidelity: 0.8452007180703056
# ########## Inner-loop Iteration 38/50 ##########
# Sampling 630 points from training dataset with (94334, 94334) entries
# Student model 9-38 trained with depth 10 and 40 leaves:
# Student model score: 0.8390837182722987
# Student model 9-38 fidelity: 0.8390837182722987
# ########## Inner-loop Iteration 39/50 ##########
# Sampling 630 points from training dataset with (94523, 94523) entries
# Student model 9-39 trained with depth 11 and 41 leaves:
# Student model score: 0.7618897231800458
# Student model 9-39 fidelity: 0.7618897231800458
# ########## Inner-loop Iteration 40/50 ##########
# Sampling 630 points from training dataset with (94712, 94712) entries
# Student model 9-40 trained with depth 14 and 49 leaves:
# Student model score: 0.8764407695142328
# Student model 9-40 fidelity: 0.8764407695142328
# ########## Inner-loop Iteration 41/50 ##########
# Sampling 630 points from training dataset with (94901, 94901) entries
# Student model 9-41 trained with depth 10 and 42 leaves:
# Student model score: 0.8020518320930614
# Student model 9-41 fidelity: 0.8020518320930614
# ########## Inner-loop Iteration 42/50 ##########
# Sampling 630 points from training dataset with (95090, 95090) entries
# Student model 9-42 trained with depth 10 and 42 leaves:
# Student model score: 0.7779183634573695
# Student model 9-42 fidelity: 0.7779183634573695
# ########## Inner-loop Iteration 43/50 ##########
# Sampling 630 points from training dataset with (95279, 95279) entries
# Student model 9-43 trained with depth 11 and 47 leaves:
# Student model score: 0.7460140332313877
# Student model 9-43 fidelity: 0.7460140332313877
# ########## Inner-loop Iteration 44/50 ##########
# Sampling 630 points from training dataset with (95468, 95468) entries
# Student model 9-44 trained with depth 12 and 39 leaves:
# Student model score: 0.8156246531246533
# Student model 9-44 fidelity: 0.8156246531246533
# ########## Inner-loop Iteration 45/50 ##########
# Sampling 630 points from training dataset with (95657, 95657) entries
# Student model 9-45 trained with depth 11 and 38 leaves:
# Student model score: 0.77525040168088
# Student model 9-45 fidelity: 0.77525040168088
# ########## Inner-loop Iteration 46/50 ##########
# Sampling 630 points from training dataset with (95846, 95846) entries
# Student model 9-46 trained with depth 12 and 48 leaves:
# Student model score: 0.6522108694372568
# Student model 9-46 fidelity: 0.6522108694372568
# ########## Inner-loop Iteration 47/50 ##########
# Sampling 630 points from training dataset with (96035, 96035) entries
# Student model 9-47 trained with depth 10 and 49 leaves:
# Student model score: 0.7028212359860792
# Student model 9-47 fidelity: 0.7028212359860792
# ########## Inner-loop Iteration 48/50 ##########
# Sampling 630 points from training dataset with (96224, 96224) entries
# Student model 9-48 trained with depth 15 and 46 leaves:
# Student model score: 0.823359257857132
# Student model 9-48 fidelity: 0.823359257857132
# ########## Inner-loop Iteration 49/50 ##########
# Sampling 630 points from training dataset with (96413, 96413) entries
# Student model 9-49 trained with depth 13 and 51 leaves:
# Student model score: 0.8306256362233592
# Student model 9-49 fidelity: 0.8306256362233592

# %%
# Print the explanation results
print(f"\nModel explanation agreement: {agreement:.2f}")
print("Model explanation global fidelity report:")
print(classification_report(y_pred_simple, dt_y_pred))
print("Model explanation score report:")
print(classification_report(y_test, dt_y_pred))
# Out:
# Model explanation agreement: 0.70
# Model explanation global fidelity report:
#               precision    recall  f1-score   support
#
#            0       0.35      0.58      0.44        38
#            1       0.60      0.27      0.38        11
#            2       1.00      0.22      0.36         9
#            3       0.84      0.96      0.90       160
#            4       0.80      0.92      0.85        48
#            5       1.00      1.00      1.00       297
#            6       0.94      0.96      0.95       180
#            7       0.86      0.72      0.79       354
#            8       1.00      0.71      0.83        14
#            9       0.52      0.66      0.58        82
#           10       1.00      0.17      0.29         6
#           11       0.99      0.98      0.98        89
#
#     accuracy                           0.86      1288
#    macro avg       0.82      0.68      0.70      1288
# weighted avg       0.87      0.86      0.86      1288
#
# Model explanation score report:
#               precision    recall  f1-score   support
#
#            0       0.40      0.47      0.43        53
#            1       0.60      0.23      0.33        13
#            2       1.00      0.05      0.09        43
#            3       0.64      0.85      0.73       137
#            4       0.33      0.49      0.39        37
#            5       1.00      1.00      1.00       297
#            6       0.93      0.96      0.95       179
#            7       0.83      0.72      0.77       338
#            8       1.00      0.77      0.87        13
#            9       0.53      0.66      0.59        83
#           10       1.00      0.20      0.33         5
#           11       1.00      0.98      0.99        90
#
#     accuracy                           0.80      1288
#    macro avg       0.77      0.62      0.62      1288
# weighted avg       0.83      0.80      0.80      1288
